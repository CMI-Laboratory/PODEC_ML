# %%
import pandas as pd
import pickle,matplotlib.pyplot as plt, seaborn as sns
# %matplotlib inline
from pandas import DataFrame as df
import time,os,sys
import random
import datetime
from sklearn import datasets
import itertools
from matplotlib.colors import ListedColormap
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_moons, make_circles, make_classification, make_blobs, make_checkerboard
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cluster import KMeans
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import (RandomForestClassifier, AdaBoostClassifier, 
                              ExtraTreesClassifier, GradientBoostingClassifier, BaggingClassifier)
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
import xgboost as xgb
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

import pickle,matplotlib.pyplot as plt
# %matplotlib inline
import time,os,sys
import random
from sklearn import datasets
import itertools
from matplotlib.colors import ListedColormap
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_moons, make_circles, make_classification, make_blobs, make_checkerboard
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cluster import KMeans
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import (RandomForestClassifier, AdaBoostClassifier, 
                              ExtraTreesClassifier, GradientBoostingClassifier, BaggingClassifier)
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
import xgboost as xgb
import pandas as pd
import numpy as np
import os
from imblearn.over_sampling import SMOTE

from sklearn import linear_model
from itertools import cycle, islice
from matplotlib import pyplot as plt
from IPython.display import display, HTML
from sklearn.impute import SimpleImputer
import pickle,matplotlib.pyplot as plt
# %matplotlib inline
from pandas import DataFrame as df
import time,os,sys
import random
from sklearn import datasets
import itertools

from matplotlib.colors import ListedColormap
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_moons, make_circles, make_classification, make_blobs, make_checkerboard
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cluster import KMeans
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import (RandomForestClassifier, AdaBoostClassifier, 
                              ExtraTreesClassifier, GradientBoostingClassifier, BaggingClassifier)
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
import xgboost as xgb
import pandas as pd
import numpy as np
import os
import numpy as np
from scipy import interp
import matplotlib.pyplot as plt

from sklearn import svm, datasets
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import StratifiedKFold

from sklearn import linear_model
from itertools import cycle, islice
from matplotlib import pyplot as plt
from IPython.display import display, HTML

from sklearn.neural_network import MLPClassifier

import os
import pandas as pd
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn import metrics
from imblearn.over_sampling import SMOTE

def findfile(filename,folder):
    filefolderlist=os.listdir(folder)
    filelist=[]
    folderlist=[]
    toggle=0
    for i in filefolderlist:
        if i[-3:]=='csv':
            filelist.append(i)
        else:
            folderlist.append(i)
    for i in filelist:
        if i[:-4]==filename:
            returnfilepath=folder+i
            toggle=1
            break
    if toggle==0:
        for i in folderlist:
            hawifilelist=os.listdir(folder+i)
            for j in hawifilelist:
                if j[:-4]==filename:
                    returnfilepath=folder+i+'/'+j
                    break
    return returnfilepath

def get_anes_start_time(i):
    year=df['Anes_START'][i][:].split('-')[0]
    month=df['Anes_START'][i][:].split('-')[1]
    day=df['Anes_START'][i][:].split('-')[2].split(' ')[0]
    hour=df['Anes_START'][i][:].split(':')[0].split(' ')[1]
    minute=df['Anes_START'][i][:].split(':')[1]
    returntime=datetime.datetime(int(year),int(month),int(day),int(hour),int(minute))
    return returntime

def get_anes_end_time(i):
    year=df['Anes_END'][i][:].split('-')[0]
    month=df['Anes_END'][i][:].split('-')[1]
    day=df['Anes_END'][i][:].split('-')[2].split(' ')[0]
    hour=df['Anes_END'][i][:].split(':')[0].split(' ')[1]
    minute=df['Anes_END'][i][:].split(':')[1]
    returntime=datetime.datetime(int(year),int(month),int(day),int(hour),int(minute))
    return returntime

def get_CPB_on_time(i):
    year=df['CPB_on'][i][:].split('-')[0]
    month=df['CPB_on'][i][:].split('-')[1]
    day=df['CPB_on'][i][:].split('-')[2].split(' ')[0]
    hour=df['CPB_on'][i][:].split(':')[0].split(' ')[1]
    minute=df['CPB_on'][i][:].split(':')[1]
    returntime=datetime.datetime(int(year),int(month),int(day),int(hour),int(minute))
    return returntime

def get_CPB_off_time(i):
    year=df['CPB_off'][i][:].split('-')[0]
    month=df['CPB_off'][i][:].split('-')[1]
    day=df['CPB_off'][i][:].split('-')[2].split(' ')[0]
    hour=df['CPB_off'][i][:].split(':')[0].split(' ')[1]
    minute=df['CPB_off'][i][:].split(':')[1]
    returntime=datetime.datetime(int(year),int(month),int(day),int(hour),int(minute))
    return returntime

def get_TCA_start_time(i):
    year=df['TCA_start'][i][:].split('-')[0]
    month=df['TCA_start'][i][:].split('-')[1]
    day=df['TCA_start'][i][:].split('-')[2].split(' ')[0]
    hour=df['TCA_start'][i][:].split(':')[0].split(' ')[1]
    minute=df['TCA_start'][i][:].split(':')[1]
    returntime=datetime.datetime(int(year),int(month),int(day),int(hour),int(minute))
    return returntime

def get_TCA_end_time(i):
    year=df['TCA_end'][i][:].split('-')[0]
    month=df['TCA_end'][i][:].split('-')[1]
    day=df['TCA_end'][i][:].split('-')[2].split(' ')[0]
    hour=df['TCA_end'][i][:].split(':')[0].split(' ')[1]
    minute=df['TCA_end'][i][:].split(':')[1]
    returntime=datetime.datetime(int(year),int(month),int(day),int(hour),int(minute))
    return returntime

def get_op_start_time(i):
    year=df['Op_START'][i][:].split('-')[0]
    month=df['Op_START'][i][:].split('-')[1]
    day=df['Op_START'][i][:].split('-')[2].split(' ')[0]
    hour=df['Op_START'][i][:].split(':')[0].split(' ')[1]
    minute=df['Op_START'][i][:].split(':')[1]
    returntime=datetime.datetime(int(year),int(month),int(day),int(hour),int(minute))
    return returntime

def get_op_end_time(i):
    year=df['Op_END'][i][:].split('-')[0]
    month=df['Op_END'][i][:].split('-')[1]
    day=df['Op_END'][i][:].split('-')[2].split(' ')[0]
    hour=df['Op_END'][i][:].split(':')[0].split(' ')[1]
    minute=df['Op_END'][i][:].split(':')[1]
    returntime=datetime.datetime(int(year),int(month),int(day),int(hour),int(minute))
    return returntime

# %%
import pandas as pd
df1=pd.read_csv('postopdata4.csv',encoding='cp949')
len(df1)
df2=pd.read_csv('20221019_data_validation.csv')
len(df2)
df1columns=list(df1.columns)
df2columns=list(df2.columns)
print(len(df1columns))
print(len(df2columns))
for i in df1columns:
    if i not in df2columns:
        print(i)
for i in df2columns:
    if i not in df1columns:
        print(i)
df1_addon=pd.read_csv('20220523data.csv',encoding='cp949')
df1_addon_part=df1_addon[['no','cognitive impairment','alcohol abuse']]
df1_total=pd.merge(df1,df1_addon_part,on='no')
len(df1_addon)
for i in range(len(df2columns)):
    if df2columns[i]=='vaso_T_bi':
        print(i, "vaso")
    if df2columns[i]=='prima_T_bi':
        print(i,"prima")
    if df2columns[i]=='dobu_T_bi':
        print(i,"dobu")
    if df2columns[i]=='delirium_new':
        print(i,"delirium")
df2columns[118]='vaso_T'
df2columns[122]='prima_T'
df2columns[126]='dobu_T'
df2columns[190]='delirium'
df2.columns=df2columns
print(len(df1_total.columns))
print(len(df2columns))
d1=df1_total[df2columns]
d2=df2[df2columns]
print(len(d1))
print(len(d2))
df=pd.concat([d1,d2],axis=0)
df.reset_index(inplace=True,drop=True)

# %%
df['train_val_test']=0
for i in range(len(df)):
    if i>=1915:
        df['train_val_test'][i]='test'
    else:
        if int(df['opdate'][i][:4]+df['opdate'][i][5:7]+df['opdate'][i][8:10])>=20210601:
            df['train_val_test'][i]='val'
        else:
            df['train_val_test'][i]='train'

# %%
for i in range(len(df)):
    if i<1915:
        a=df['no'][i]-1
        if a>=0 and a<=199:
            folder="D:/postopdelirium_csv/0001_0200/0001_0200/"
        elif a>=200 and a<=399:
            folder="D:/postopdelirium_csv/0201_0400/0201_0400/"
        elif a>=400 and a<=599:
            folder="D:/postopdelirium_csv/0401_0600/0401_0600/"
        elif a>=600 and a<=799:
            folder="D:/postopdelirium_csv/0601_0800/0601_0800/"
        elif a>=800 and a<=825:
            folder="D:/postopdelirium_csv/0801_/0801_/"    
        elif a>=826 and a<=999:
            folder="D:/postopdelirium_csv/0827_1000/0827_1000/"
        elif a>=1000 and a<=1199:
            folder="D:/postopdelirium_csv/1001_1200/1001_1200/"
        elif a>=1200 and a<=1399:
            folder="D:/postopdelirium_csv/1201_1400/1201_1400/"
        elif a>=1400 and a<=1649:
            folder="D:/postopdelirium_csv/1401_1650/1401_1650/"
        elif a>=1650 and a<=1799:
            folder="D:/postopdelirium_csv/1651_1800/1651_1800/"
        else:
            folder="D:/postopdelirium_csv/1801_1968/1801_1968/"
    else:
        folder="E:/Workspace/Data/Postopdelirium/postopdelirium_validation_csv/delirium_validation_vitaldb_1_210/"

    
    rSO2_total=pd.DataFrame(columns=['Time','rSO2_L','rSO2_R'])
    dftemp_final1=pd.DataFrame(columns=['Time','rSO2_L','rSO2_R'])
    dftemp_final2=pd.DataFrame(columns=['Time','rSO2_L','rSO2_R'])
    
    for filefile in ['파일이름_01','파일이름_02','파일이름_03','파일이름_04','파일이름_05','파일이름_06','파일이름_07','파일이름_08']:      
        try:
            dat=pd.read_csv(findfile(df[filefile][i],folder))

            try:
                dat['Root/SO2_1']
                datcolumns=list(dat.columns)

                so2_1_columns=[]
                so2_2_columns=[]
                for c in datcolumns:
                    #print()
                    if c[:10]=='Root/SO2_1':
                        so2_1_columns.append(c)
                    if c[:10]=='Root/SO2_2':
                        so2_2_columns.append(c)
                dfcount=0   

                for c in so2_1_columns:
                    for d in so2_2_columns:

                        globals()['dftemp_{}'.format(dfcount)]=dat[['Time',c,d]]
                        globals()['dftemp_{}'.format(dfcount)].columns=['Time','rSO2_L','rSO2_R']
                        globals()['dftemp_{}'.format(dfcount)]=globals()['dftemp_{}'.format(dfcount)].dropna(axis=0)
                        #print(dftemp_0)
                        dfcount+=1
                
                for c in range(dfcount):
                    dftemp_final1=pd.concat([dftemp_final1,globals()['dftemp_{}'.format(c)]])

            except:
                pass
                    

            try:
                dat['Invos/SCO2_L']
                datcolumns=list(dat.columns)
                so2_1_columns=[]
                so2_2_columns=[]
                for c in datcolumns:
                    if c[:12]=='Invos/SCO2_L':
                        so2_1_columns.append(c)
                    if c[:12]=='Invos/SCO2_R':
                        so2_2_columns.append(c)
                dfcount=0        
                for c in so2_1_columns:
                    for d in so2_2_columns:
                        globals()['dftemp_{}'.format(dfcount)]=dat[['Time',c,d]]
                        globals()['dftemp_{}'.format(dfcount)].columns=['Time','rSO2_L','rSO2_R']
                        globals()['dftemp_{}'.format(dfcount)]=globals()['dftemp_{}'.format(dfcount)].dropna(axis=0)
                        #print(dftemp_0)
                        dfcount+=1
                
                for c in range(dfcount):
                    dftemp_final2=pd.concat([dftemp_final2,globals()['dftemp_{}'.format(c)]])
                    #print(dftemp_final2)
            except:
                pass

        except:
            pass

    rSO2_total=pd.concat([dftemp_final1,dftemp_final2])   
    

    rSO2_total=rSO2_total.dropna(axis=0)
    rSO2_total=rSO2_total[rSO2_total['rSO2_L']!=0]
    rSO2_total=rSO2_total[rSO2_total['rSO2_R']!=0]
    rSO2_total.drop_duplicates(inplace=True)
    rSO2_total.sort_values(by=['Time'],axis=0,inplace=True)

    rSO2_total.reset_index(inplace=True,drop=True)
    rSO2_total['rSO2_mean']=(rSO2_total['rSO2_L']+rSO2_total['rSO2_R'])/2



    rSO2_total['year']=rSO2_total['Time'].str[:4]
    rSO2_total['month']=rSO2_total['Time'].str[5:7]
    rSO2_total['day']=rSO2_total['Time'].str[8:10]
    rSO2_total['hour']=rSO2_total['Time'].str[11:13]
    rSO2_total['minute']=rSO2_total['Time'].str[14:16]
    rSO2_total['second']=rSO2_total['Time'].str[17:19]
    rSO2_total['year']=pd.to_numeric(rSO2_total['year'])
    rSO2_total['month']=pd.to_numeric(rSO2_total['month'])
    rSO2_total['day']=pd.to_numeric(rSO2_total['day'])
    rSO2_total['hour']=pd.to_numeric(rSO2_total['hour'])
    rSO2_total['minute']=pd.to_numeric(rSO2_total['minute'])
    rSO2_total['second']=pd.to_numeric(rSO2_total['second'])
    rSO2_total['second2']=(rSO2_total['second']//5)*5


    rSO2_total['timetime']=rSO2_total['Time'].str[:17]+('0'+rSO2_total['second2'].astype(str)).str[-2:]
    rSO2_total['datetime']=pd.to_datetime(rSO2_total['timetime'],format="%Y-%m-%d %H:%M:%S")



    rSO2_total2=rSO2_total[['rSO2_mean','datetime']]

    rSO2_total2.drop_duplicates(inplace=True)
    rSO2_total2.reset_index(inplace=True,drop=True)

    rSO2_total2.to_csv("D:/postopdelirium_parameters/rSO2/"+str(i)+'.csv')
    print(i)

# %%
avail=[]

for i in range(len(df)):
    if True: ########### 
        try:
            anes_end_time=get_anes_end_time(i)
            anes_start_time=get_anes_start_time(i)

            total_anes_time=(anes_end_time-anes_start_time).seconds
            rSO2_df=pd.read_csv("D:/postopdelirium_parameters/rSO2/"+str(i)+'.csv')
            rSO2_df['datetime']=pd.to_datetime(rSO2_df['datetime'],format="%Y-%m-%d %H:%M:%S")
            count=0
            for j in range(len(rSO2_df)):

                timestamp=rSO2_df['datetime'][j]
                if timestamp>=anes_start_time and timestamp<=anes_end_time:
                    count+=1
            avail.append(count/(total_anes_time//5))
            print(i)
        except:
            print(i,'error')  
            avail.append(0)
    else:
        print('excluded')
        avail.append(0)
df['rSO2_avail']=avail

# %%
np.mean(df['rSO2_avail'])

# %%
##baseline rso2
baseline_rSO2_list=[]

for i in range(len(df)):
    if True:
        rSO2_df=pd.read_csv("D:/postopdelirium_parameters/rSO2/"+str(i)+'.csv')
        rSO2_df['datetime']=pd.to_datetime(rSO2_df['datetime'],format="%Y-%m-%d %H:%M:%S")
        try:
            #anes_end_time=get_anes_end_time(i)
            anes_start_time=get_anes_start_time(i)
            #op_end_time=get_op_end_time(i)
            op_start_time=get_op_start_time(i)

            first_rSO2=0
            first_rSO2_time=0

            for j in range(len(rSO2_df)):
                #if rSO2_df['datetime'][j]>=anes_start_time and rSO2_df['datetime'][j]<op_start_time:
                if rSO2_df['datetime'][j]>=anes_start_time:
                    first_rSO2=rSO2_df['rSO2_mean'][j]
                    first_rSO2_time=rSO2_df['datetime'][j]
                    break

            baselines=[]
            if first_rSO2_time!=0:
                for j in range(12):
                    thetime=first_rSO2_time+datetime.timedelta(seconds=5*j)
                    try:
                        therSO2=rSO2_df[rSO2_df['datetime']==thetime]['rSO2_mean'].item()
                        baselines.append(therSO2)
                    except:
                        baselines.append(np.nan)
                baselines=pd.Series(baselines)
                baselines.interpolate(inplace=True)
                baselines=list(baselines)
                baseline_rSO2=np.mean(baselines)
                if np.isnan(baseline_rSO2)==False:
                    baseline_rSO2_list.append(baseline_rSO2)
                else:
                    baseline_rSO2_list.append(np.nan)
                    print('======nan======')
            else:
                baseline_rSO2_list.append(np.nan)
                print('======nan======')

            #print(i)

        except:
            print(i,'error')
            baseline_rSO2_list.append(np.nan)
    else:
        print('excluded')
        baseline_rSO2_list.append(np.nan)
df['baseline_rSO2']=baseline_rSO2_list

# %%
##lowest,average,CV,ARV, intraoperative rso2
## abs_40_duration,abs_50_duration,rel_80_duration, rel_75_duration, rel_70_duration
## abs_auc_40, abs_auc_50, rel_auc_80, rel_auc_75, rel_auc_70

lowest_rSO2_list=[]
average_rSO2_list=[]
CV_rSO2_list=[]
ARV_rSO2_list=[]
abs_40_duration_rSO2_list=[]
abs_50_duration_rSO2_list=[]
rel_80_duration_rSO2_list=[]
rel_75_duration_rSO2_list=[]
rel_70_duration_rSO2_list=[]
abs_auc_40_rSO2_list=[]
abs_auc_50_rSO2_list=[]
rel_auc_80_rSO2_list=[]
rel_auc_75_rSO2_list=[]
rel_auc_70_rSO2_list=[]


for i in range(len(df)):
    if True:
        rSO2_df=pd.read_csv("D:/postopdelirium_parameters/rSO2/"+str(i)+'.csv')
        rSO2_df['datetime']=pd.to_datetime(rSO2_df['datetime'],format="%Y-%m-%d %H:%M:%S")

        rSO2_values=[]

        lowest_rSO2=np.nan
        average_rSO2=np.nan
        CV_rSO2=np.nan
        ARV_rSO2=np.nan
        abs_40_duration_rSO2=np.nan
        abs_50_duration_rSO2=np.nan
        rel_80_duration_rSO2=np.nan
        rel_75_duration_rSO2=np.nan
        rel_70_duration_rSO2=np.nan
        abs_auc_40_rSO2=np.nan
        abs_auc_50_rSO2=np.nan
        rel_auc_80_rSO2=np.nan
        rel_auc_75_rSO2=np.nan
        rel_auc_70_rSO2=np.nan

        try:
            count_abs_40=0
            count_abs_50=0
            count_rel_80=0
            count_rel_75=0
            count_rel_70=0
            area_abs_40=0
            area_abs_50=0
            area_rel_80=0
            area_rel_75=0
            area_rel_70=0

            anes_end_time=get_anes_end_time(i)
            anes_start_time=get_anes_start_time(i)


            for j in range(len(rSO2_df)):
                if rSO2_df['datetime'][j]>=anes_start_time and rSO2_df['datetime'][j]<=anes_end_time:
                    rSO2_values.append(rSO2_df['rSO2_mean'][j].item())

            lowest_rSO2=np.min(rSO2_values)
            average_rSO2=np.mean(rSO2_values)
            CV_rSO2=np.std(rSO2_values)/np.mean(rSO2_values)

            real_variation=[]

            for j in range(len(rSO2_values)-1):
                real_variation.append(abs(rSO2_values[j+1]-rSO2_values[j]))

            ARV_rSO2=np.mean(real_variation)

            for j in range(len(rSO2_values)): 
                if rSO2_values[j]<40:
                    count_abs_40+=1
                    area_abs_40+=(40-rSO2_values[j])
                if rSO2_values[j]<50:
                    count_abs_50+=1
                    area_abs_50+=(50-rSO2_values[j])
                if np.isnan(df['baseline_rSO2'][i])==False:
                    if rSO2_values[j]<df['baseline_rSO2'][i]*0.8:
                        count_rel_80+=1
                        area_rel_80+=(df['baseline_rSO2'][i]*0.8-rSO2_values[j])
                    if rSO2_values[j]<df['baseline_rSO2'][i]*0.75:
                        count_rel_75+=1
                        area_rel_75+=(df['baseline_rSO2'][i]*0.75-rSO2_values[j])
                    if rSO2_values[j]<df['baseline_rSO2'][i]*0.7:
                        count_rel_70+=1
                        area_rel_70+=(df['baseline_rSO2'][i]*0.7-rSO2_values[j])

            lowest_rSO2_list.append(lowest_rSO2)
            average_rSO2_list.append(average_rSO2)
            CV_rSO2_list.append(CV_rSO2)
            ARV_rSO2_list.append(ARV_rSO2)
            abs_40_duration_rSO2_list.append(count_abs_40)
            abs_50_duration_rSO2_list.append(count_abs_50)
            rel_80_duration_rSO2_list.append(count_rel_80)
            rel_75_duration_rSO2_list.append(count_rel_75)
            rel_70_duration_rSO2_list.append(count_rel_70)
            abs_auc_40_rSO2_list.append(area_abs_40)
            abs_auc_50_rSO2_list.append(area_abs_50)
            rel_auc_80_rSO2_list.append(area_rel_80)
            rel_auc_75_rSO2_list.append(area_rel_75)
            rel_auc_70_rSO2_list.append(area_rel_70)

        except:
            print(i,'error')
            lowest_rSO2_list.append(lowest_rSO2)
            average_rSO2_list.append(average_rSO2)
            CV_rSO2_list.append(CV_rSO2)
            ARV_rSO2_list.append(ARV_rSO2)
            abs_40_duration_rSO2_list.append(count_abs_40)
            abs_50_duration_rSO2_list.append(count_abs_50)
            rel_80_duration_rSO2_list.append(count_rel_80)
            rel_75_duration_rSO2_list.append(count_rel_75)
            rel_70_duration_rSO2_list.append(count_rel_70)
            abs_auc_40_rSO2_list.append(area_abs_40)
            abs_auc_50_rSO2_list.append(area_abs_50)
            rel_auc_80_rSO2_list.append(area_rel_80)
            rel_auc_75_rSO2_list.append(area_rel_75)
            rel_auc_70_rSO2_list.append(area_rel_70)
    else:
        print(i, '========excluded=======')
        lowest_rSO2=np.nan
        average_rSO2=np.nan
        CV_rSO2=np.nan
        ARV_rSO2=np.nan
        abs_40_duration_rSO2=np.nan
        abs_50_duration_rSO2=np.nan
        rel_80_duration_rSO2=np.nan
        rel_75_duration_rSO2=np.nan
        rel_70_duration_rSO2=np.nan
        abs_auc_40_rSO2=np.nan
        abs_auc_50_rSO2=np.nan
        rel_auc_80_rSO2=np.nan
        rel_auc_75_rSO2=np.nan
        rel_auc_70_rSO2=np.nan
        lowest_rSO2_list.append(lowest_rSO2)
        average_rSO2_list.append(average_rSO2)
        CV_rSO2_list.append(CV_rSO2)
        ARV_rSO2_list.append(ARV_rSO2)
        abs_40_duration_rSO2_list.append(count_abs_40)
        abs_50_duration_rSO2_list.append(count_abs_50)
        rel_80_duration_rSO2_list.append(count_rel_80)
        rel_75_duration_rSO2_list.append(count_rel_75)
        rel_70_duration_rSO2_list.append(count_rel_70)
        abs_auc_40_rSO2_list.append(area_abs_40)
        abs_auc_50_rSO2_list.append(area_abs_50)
        rel_auc_80_rSO2_list.append(area_rel_80)
        rel_auc_75_rSO2_list.append(area_rel_75)
        rel_auc_70_rSO2_list.append(area_rel_70)



df['lowest_rSO2']=lowest_rSO2_list
df['average_rSO2']=average_rSO2_list
df['CV_rSO2']=CV_rSO2_list
df['ARV_rSO2']=ARV_rSO2_list
df['abs_40_duration_rSO2']=abs_40_duration_rSO2_list
df['abs_50_duration_rSO2']=abs_50_duration_rSO2_list
df['rel_80_duration_rSO2']=rel_80_duration_rSO2_list
df['rel_75_duration_rSO2']=rel_75_duration_rSO2_list
df['rel_70_duration_rSO2']=rel_70_duration_rSO2_list
df['abs_auc_40_rSO2']=abs_auc_40_rSO2_list
df['abs_auc_50_rSO2']=abs_auc_50_rSO2_list
df['rel_auc_80_rSO2']=rel_auc_80_rSO2_list
df['rel_auc_75_rSO2']=rel_auc_75_rSO2_list
df['rel_auc_70_rSO2']=rel_auc_70_rSO2_list

# %%
df.to_csv('postop5cha_temp')

# %%
df=pd.read_csv('postop5cha_temp')
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
for i in range(len(df)):

    if i<1915:
        a=df['no'][i]-1
        if a>=0 and a<=199:
            folder="D:/postopdelirium_csv/0001_0200/0001_0200/"
        elif a>=200 and a<=399:
            folder="D:/postopdelirium_csv/0201_0400/0201_0400/"
        elif a>=400 and a<=599:
            folder="D:/postopdelirium_csv/0401_0600/0401_0600/"
        elif a>=600 and a<=799:
            folder="D:/postopdelirium_csv/0601_0800/0601_0800/"
        elif a>=800 and a<=825:
            folder="D:/postopdelirium_csv/0801_/0801_/"    
        elif a>=826 and a<=999:
            folder="D:/postopdelirium_csv/0827_1000/0827_1000/"
        elif a>=1000 and a<=1199:
            folder="D:/postopdelirium_csv/1001_1200/1001_1200/"
        elif a>=1200 and a<=1399:
            folder="D:/postopdelirium_csv/1201_1400/1201_1400/"
        elif a>=1400 and a<=1649:
            folder="D:/postopdelirium_csv/1401_1650/1401_1650/"
        elif a>=1650 and a<=1799:
            folder="D:/postopdelirium_csv/1651_1800/1651_1800/"
        else:
            folder="D:/postopdelirium_csv/1801_1968/1801_1968/"

    else:
        folder="E:/Workspace/Data/Postopdelirium/postopdelirium_validation_csv/delirium_validation_vitaldb_1_210/"


    EEG_total=pd.DataFrame(columns=['Time','EEG_value', 'EEG_SR','EEG_quality','EEG_type'])
    dftemp_final1=pd.DataFrame(columns=['Time','EEG_value', 'EEG_SR','EEG_quality','EEG_type'])
    dftemp_final2=pd.DataFrame(columns=['Time','EEG_value', 'EEG_SR','EEG_quality','EEG_type'])
    
    for filefile in ['파일이름_01','파일이름_02','파일이름_03','파일이름_04','파일이름_05','파일이름_06','파일이름_07','파일이름_08']:      

        try:
            #print(df[filefile][i])
            dat=pd.read_csv(findfile(df[filefile][i],folder))


            try:
                dat['BIS/BIS']
                datcolumns=list(dat.columns)
                bis_columns=[]
                sr_columns=[]
                sqi_columns=[]
                for c in datcolumns:
                    if c[:7]=='BIS/BIS':
                        bis_columns.append(c)
                    if c[:6]=='BIS/SR':
                        sr_columns.append(c)
                    if c[:7]=='BIS/SQI':
                        sqi_columns.append(c)
                dfcount=0
                
                for c in bis_columns:
                    for d in sr_columns:
                        for e in sqi_columns:
                            globals()['dftemp_{}'.format(dfcount)]=dat[['Time',c,d,e]]
                            globals()['dftemp_{}'.format(dfcount)].columns=['Time','EEG_value', 'EEG_SR','EEG_quality']
                            globals()['dftemp_{}'.format(dfcount)]=globals()['dftemp_{}'.format(dfcount)].dropna(axis=0)
                            globals()['dftemp_{}'.format(dfcount)]['EEG_type']='BIS'
                            dfcount+=1
                            
                for c in range(dfcount):
                    dftemp_final1=pd.concat([dftemp_final1,globals()['dftemp_{}'.format(c)]])
            except:

                pass
                

            try:
                dat['Root/PSI']
                datcolumns=list(dat.columns)
                psi_columns=[]
                sr_columns=[]
                artf_columns=[]
                for c in datcolumns:
                    if c[:8]=='Root/PSI':
                        psi_columns.append(c)
                    if c[:7]=='Root/SR':
                        sr_columns.append(c)
                    if c[:9]=='Root/ARTF':
                        artf_columns.append(c)

                dfcount=0
                for c in psi_columns:
                    for d in sr_columns:
                        for e in artf_columns:
                            globals()['dftemp_{}'.format(dfcount)]=dat[['Time',c,d,e]]
                            globals()['dftemp_{}'.format(dfcount)].columns=['Time','EEG_value', 'EEG_SR','EEG_quality']
                            globals()['dftemp_{}'.format(dfcount)]=globals()['dftemp_{}'.format(dfcount)].dropna(axis=0)
                            globals()['dftemp_{}'.format(dfcount)]['EEG_type']='PSI'
                            dfcount+=1          
                for c in range(dfcount):
                    dftemp_final2=pd.concat([dftemp_final2,globals()['dftemp_{}'.format(c)]])
            except:

                pass
            
                
        except:
            pass


    EEG_total=pd.concat([dftemp_final1,dftemp_final2])  
    EEG_total=EEG_total.dropna(axis=0)
    EEG_total.drop_duplicates(inplace=True)

    EEG_total.sort_values(by=['Time'],axis=0,inplace=True)

    EEG_total.reset_index(inplace=True,drop=True)


    

    EEG_total['year']=EEG_total['Time'].str[:4]
    EEG_total['month']=EEG_total['Time'].str[5:7]
    EEG_total['day']=EEG_total['Time'].str[8:10]
    EEG_total['hour']=EEG_total['Time'].str[11:13]
    EEG_total['minute']=EEG_total['Time'].str[14:16]
    EEG_total['second']=EEG_total['Time'].str[17:19]
    EEG_total['year']=pd.to_numeric(EEG_total['year'])
    EEG_total['month']=pd.to_numeric(EEG_total['month'])
    EEG_total['day']=pd.to_numeric(EEG_total['day'])
    EEG_total['hour']=pd.to_numeric(EEG_total['hour'])
    EEG_total['minute']=pd.to_numeric(EEG_total['minute'])
    EEG_total['second']=pd.to_numeric(EEG_total['second'])
    EEG_total['second2']=(EEG_total['second']//5)*5


    EEG_total['timetime']=EEG_total['Time'].str[:17]+('0'+EEG_total['second2'].astype(str)).str[-2:]
    EEG_total['datetime']=pd.to_datetime(EEG_total['timetime'],format="%Y-%m-%d %H:%M:%S")

    #rSO2_total2.drop_duplicates(inplace=True)
    #rSO2_total2.reset_index(inplace=True,drop=True)

    EEG_total2=EEG_total[['datetime','EEG_value', 'EEG_SR','EEG_quality','EEG_type']]

    EEG_total2.drop_duplicates(inplace=True)
    EEG_total2.reset_index(inplace=True,drop=True)


    EEG_total2.to_csv("D:/postopdelirium_parameters/EEG/"+str(i)+'.csv')

    print(i)

# %%
avail_BIS=[]
avail_PSI=[]

for i in range(len(df)):
    if True: 
        try:
            anes_end_time=get_anes_end_time(i)
            anes_start_time=get_anes_start_time(i)

            total_anes_time=(anes_end_time-anes_start_time).seconds
            EEG_df=pd.read_csv("D:/postopdelirium_parameters/EEG/"+str(i)+'.csv')
            EEG_df['datetime']=pd.to_datetime(EEG_df['datetime'],format="%Y-%m-%d %H:%M:%S")
            PSI_count=0
            BIS_count=0
            for j in range(len(EEG_df)):

                timestamp=EEG_df['datetime'][j]
                if timestamp>=anes_start_time and timestamp<=anes_end_time and EEG_df['EEG_type'][j]=='PSI':
                    PSI_count+=1
                if timestamp>=anes_start_time and timestamp<=anes_end_time and EEG_df['EEG_type'][j]=='BIS':
                    BIS_count+=1
            avail_PSI.append(PSI_count/(total_anes_time//5))
            avail_BIS.append(BIS_count/(total_anes_time//5))

        except:
            print(i,'error')  
            avail_PSI.append(0)
            avail_BIS.append(0)
    else:
        print(i,'===excluded===')
        avail_PSI.append(0)
        avail_BIS.append(0)
df['EEG_avail_PSI']=avail_PSI
df['EEG_avail_BIS']=avail_BIS

# %%
EEG_type_list=[]

biscount=0
for i in range(len(df)):
    bis_avail=df['EEG_avail_BIS'][i]
    psi_avail=df['EEG_avail_PSI'][i]
    if bis_avail!=0 or psi_avail!=0:
        if bis_avail>=psi_avail:
            EEG_type='BIS'
            biscount+=1
        else:
            EEG_type='PSI'
        EEG_type_list.append(EEG_type)
    else:
        EEG_type_list.append(np.nan)
        print(i,'====nan=====')

    
df['EEG_type']=EEG_type_list
print(biscount)

# %%
avail=[]
for i in range(len(df)):
    eegtype=df['EEG_type'][i]
    bis_avail=df['EEG_avail_BIS'][i]
    psi_avail=df['EEG_avail_PSI'][i]
    if eegtype=='BIS':
        avail.append(bis_avail)
    else:
        avail.append(psi_avail)
df['EEG_avail']=avail

# %%
## BIS_40_duration, PSI_25_duration
## SR_1_duration
## BIS_auc_40, PSI_auc_25
## SR_auc_1


EEG_value_duration_list=[]
EEG_SR_duration_list=[]
EEG_value_auc_list=[]
EEG_SR_auc_list=[]



for i in range(len(df)):
    if True: 
        EEG_df=pd.read_csv("D:/postopdelirium_parameters/EEG/"+str(i)+'.csv')
        EEG_df['datetime']=pd.to_datetime(EEG_df['datetime'],format="%Y-%m-%d %H:%M:%S")

        EEG_values=[]
        EEG_SRs=[]
        EEG_qualitys=[]

        try:
            anes_end_time=get_anes_end_time(i)
            anes_start_time=get_anes_start_time(i)


            for j in range(len(EEG_df)):
                if EEG_df['datetime'][j]>=anes_start_time and EEG_df['datetime'][j]<=anes_end_time:
                    EEG_values.append(EEG_df['EEG_value'][j].item())
                    EEG_SRs.append(EEG_df['EEG_SR'][j].item())
                    EEG_qualitys.append(EEG_df['EEG_quality'][j].item())


            count_value=0
            count_SR=0

            area_value=0
            area_SR=0

            if df['EEG_type'][i]=='BIS' or df['EEG_type'][i]=='PSI':
                if df['EEG_type'][i]=='BIS':
                    for j in range(len(EEG_values)):
                        if EEG_values[j]<40 and EEG_qualitys[j]>=50:
                            count_value+=1
                            area_value+=(40-EEG_values[j])
                        if EEG_SRs[j]>1 and EEG_qualitys[j]>=50:
                            count_SR+=1
                            area_SR+=(EEG_SRs[j]-1)
                else:
                    for j in range(len(EEG_values)):
                        if EEG_values[j]<25:
                            count_value+=1
                            area_value+=(25-EEG_values[j])
                        if EEG_SRs[j]>1:
                            count_SR+=1
                            area_SR+=(EEG_SRs[j]-1)

                EEG_value_duration_list.append(count_value)
                EEG_SR_duration_list.append(count_SR)
                EEG_value_auc_list.append(area_value)
                EEG_SR_auc_list.append(area_SR)

            else:
                EEG_value_duration_list.append(np.nan)
                EEG_SR_duration_list.append(np.nan)
                EEG_value_auc_list.append(np.nan)
                EEG_SR_auc_list.append(np.nan)
                print(i,'=====nan=======')


        except:
            print(i,'========error=========')
            EEG_value_duration_list.append(np.nan)
            EEG_SR_duration_list.append(np.nan)
            EEG_value_auc_list.append(np.nan)
            EEG_SR_auc_list.append(np.nan)
    else:
        print(i,'===excluded===')
        EEG_value_duration_list.append(np.nan)
        EEG_SR_duration_list.append(np.nan)
        EEG_value_auc_list.append(np.nan)
        EEG_SR_auc_list.append(np.nan)
    
        
        
df['EEG_value_duration']=EEG_value_duration_list
df['EEG_SR_duration']=EEG_SR_duration_list
df['EEG_value_auc']=EEG_value_auc_list
df['EEG_SR_auc']=EEG_SR_auc_list

# %%
np.mean(df['EEG_avail'])

# %%
df.to_csv('postop5cha_temp2.csv')

# %%
for i in range(len(df)):

    if i<1915:
        a=df['no'][i]-1
        if a>=0 and a<=199:
            folder="D:/postopdelirium_csv/0001_0200/0001_0200/"
        elif a>=200 and a<=399:
            folder="D:/postopdelirium_csv/0201_0400/0201_0400/"
        elif a>=400 and a<=599:
            folder="D:/postopdelirium_csv/0401_0600/0401_0600/"
        elif a>=600 and a<=799:
            folder="D:/postopdelirium_csv/0601_0800/0601_0800/"
        elif a>=800 and a<=825:
            folder="D:/postopdelirium_csv/0801_/0801_/"    
        elif a>=826 and a<=999:
            folder="D:/postopdelirium_csv/0827_1000/0827_1000/"
        elif a>=1000 and a<=1199:
            folder="D:/postopdelirium_csv/1001_1200/1001_1200/"
        elif a>=1200 and a<=1399:
            folder="D:/postopdelirium_csv/1201_1400/1201_1400/"
        elif a>=1400 and a<=1649:
            folder="D:/postopdelirium_csv/1401_1650/1401_1650/"
        elif a>=1650 and a<=1799:
            folder="D:/postopdelirium_csv/1651_1800/1651_1800/"
        else:
            folder="D:/postopdelirium_csv/1801_1968/1801_1968/"
    else:
        folder="E:/Workspace/Data/Postopdelirium/postopdelirium_validation_csv/delirium_validation_vitaldb_1_210/"


    MAP_CVP_total=pd.DataFrame(columns=['Time','MAP', 'CVP','MAP_name'])
    dftemp_final1=pd.DataFrame(columns=['Time','MAP', 'CVP','MAP_name'])
    dftemp_final2=pd.DataFrame(columns=['Time','MAP', 'CVP','MAP_name'])
    for filefile in ['파일이름_01','파일이름_02','파일이름_03','파일이름_04','파일이름_05','파일이름_06','파일이름_07','파일이름_08']:      
        try:
            dat=pd.read_csv(findfile(df[filefile][i],folder))
            try:
                dat['Intellivue/ART_MEAN']
                datcolumns=list(dat.columns)
                art_columns=[]
                cvp_columns=[]
                for c in datcolumns:
                    if c[:19]=='Intellivue/ART_MEAN':
                        art_columns.append(c)
                    if c[:19]=='Intellivue/CVP_MEAN':
                        cvp_columns.append(c)
                dfcount=0
                for c in art_columns:
                    for d in cvp_columns:
                        globals()['dftemp_{}'.format(dfcount)]=dat[['Time',c,d]]
                        globals()['dftemp_{}'.format(dfcount)].columns=['Time','MAP','CVP']
                        globals()['dftemp_{}'.format(dfcount)]=globals()['dftemp_{}'.format(dfcount)].dropna(axis=0)
                        globals()['dftemp_{}'.format(dfcount)]['MAP_name']='ART'

                        dfcount+=1
                for c in range(dfcount):
                    dftemp_final1=pd.concat([dftemp_final1,globals()['dftemp_{}'.format(c)]])
            except:
                pass


        except:
            pass


    MAP_CVP_total=dftemp_final1 

    MAP_CVP_total=MAP_CVP_total.dropna(axis=0)

    MAP_CVP_total.drop_duplicates(inplace=True)
    MAP_CVP_total.sort_values(by=['Time'],axis=0,inplace=True)

    MAP_CVP_total.reset_index(inplace=True,drop=True)


    MAP_CVP_total['year']=MAP_CVP_total['Time'].str[:4]
    MAP_CVP_total['month']=MAP_CVP_total['Time'].str[5:7]
    MAP_CVP_total['day']=MAP_CVP_total['Time'].str[8:10]
    MAP_CVP_total['hour']=MAP_CVP_total['Time'].str[11:13]
    MAP_CVP_total['minute']=MAP_CVP_total['Time'].str[14:16]
    MAP_CVP_total['second']=MAP_CVP_total['Time'].str[17:19]
    MAP_CVP_total['year']=pd.to_numeric(MAP_CVP_total['year'])
    MAP_CVP_total['month']=pd.to_numeric(MAP_CVP_total['month'])
    MAP_CVP_total['day']=pd.to_numeric(MAP_CVP_total['day'])
    MAP_CVP_total['hour']=pd.to_numeric(MAP_CVP_total['hour'])
    MAP_CVP_total['minute']=pd.to_numeric(MAP_CVP_total['minute'])
    MAP_CVP_total['second']=pd.to_numeric(MAP_CVP_total['second'])
    MAP_CVP_total['second2']=(MAP_CVP_total['second']//5)*5


    MAP_CVP_total['timetime']=MAP_CVP_total['Time'].str[:17]+('0'+MAP_CVP_total['second2'].astype(str)).str[-2:]
    MAP_CVP_total['datetime']=pd.to_datetime(MAP_CVP_total['timetime'],format="%Y-%m-%d %H:%M:%S")


    MAP_CVP_total2=MAP_CVP_total[['datetime','MAP', 'CVP','MAP_name']]

    MAP_CVP_total2.drop_duplicates(inplace=True)
    MAP_CVP_total2.reset_index(inplace=True,drop=True)


    MAP_CVP_total2['MAP_drop']=0
    for j in range(len(MAP_CVP_total2)):
        if MAP_CVP_total2['MAP'][j]<=30:
            droptimelist=[]
            for k in range(-6,7):
                droptime=MAP_CVP_total2['datetime'][j]+datetime.timedelta(seconds=5*k)
                droptimelist.append(droptime)
            for k in range(len(droptimelist)):
                try:
                    MAP_CVP_total2.loc[MAP_CVP_total2['datetime'] == droptimelist[k], 'MAP_drop'] = 1
                except:
                    pass

    MAP_CVP_total2['CVP_drop']=0
    for j in range(len(MAP_CVP_total2)):
        if MAP_CVP_total2['CVP'][j]>=100:
            droptimelist=[]
            for k in range(-6,7):
                droptime=MAP_CVP_total2['datetime'][j]+datetime.timedelta(seconds=5*k)
                droptimelist.append(droptime)
            for k in range(len(droptimelist)):
                try:
                    MAP_CVP_total2.loc[MAP_CVP_total2['datetime'] == droptimelist[k], 'CVP_drop'] = 1
                except:
                    pass


    MAP_CVP_total2.to_csv("D:/postopdelirium_parameters/MAP_CVP_ART/"+str(i)+'.csv')

# %%
for i in range(len(df)):

    if i<1915:
        a=df['no'][i]-1
        if a>=0 and a<=199:
            folder="D:/postopdelirium_csv/0001_0200/0001_0200/"
        elif a>=200 and a<=399:
            folder="D:/postopdelirium_csv/0201_0400/0201_0400/"
        elif a>=400 and a<=599:
            folder="D:/postopdelirium_csv/0401_0600/0401_0600/"
        elif a>=600 and a<=799:
            folder="D:/postopdelirium_csv/0601_0800/0601_0800/"
        elif a>=800 and a<=825:
            folder="D:/postopdelirium_csv/0801_/0801_/"    
        elif a>=826 and a<=999:
            folder="D:/postopdelirium_csv/0827_1000/0827_1000/"
        elif a>=1000 and a<=1199:
            folder="D:/postopdelirium_csv/1001_1200/1001_1200/"
        elif a>=1200 and a<=1399:
            folder="D:/postopdelirium_csv/1201_1400/1201_1400/"
        elif a>=1400 and a<=1649:
            folder="D:/postopdelirium_csv/1401_1650/1401_1650/"
        elif a>=1650 and a<=1799:
            folder="D:/postopdelirium_csv/1651_1800/1651_1800/"
        else:
            folder="D:/postopdelirium_csv/1801_1968/1801_1968/"
    else:
        folder="E:/Workspace/Data/Postopdelirium/postopdelirium_validation_csv/delirium_validation_vitaldb_1_210/"


    MAP_CVP_total=pd.DataFrame(columns=['Time','MAP', 'CVP','MAP_name'])
    dftemp_final1=pd.DataFrame(columns=['Time','MAP', 'CVP','MAP_name'])
    dftemp_final2=pd.DataFrame(columns=['Time','MAP', 'CVP','MAP_name'])
    for filefile in ['파일이름_01','파일이름_02','파일이름_03','파일이름_04','파일이름_05','파일이름_06','파일이름_07','파일이름_08']:      
        try:
            dat=pd.read_csv(findfile(df[filefile][i],folder))


            try:
                dat['Intellivue/ABP_MEAN']
                datcolumns=list(dat.columns)
                abp_columns=[]
                cvp_columns=[]
                for c in datcolumns:
                    if c[:19]=='Intellivue/ABP_MEAN':
                        abp_columns.append(c)
                    if c[:19]=='Intellivue/CVP_MEAN':
                        cvp_columns.append(c)
                dfcount=0
                for c in abp_columns:
                    for d in cvp_columns:
                        globals()['dftemp_{}'.format(dfcount)]=dat[['Time',c,d]]
                        globals()['dftemp_{}'.format(dfcount)].columns=['Time','MAP','CVP']
                        globals()['dftemp_{}'.format(dfcount)]=globals()['dftemp_{}'.format(dfcount)].dropna(axis=0)
                        globals()['dftemp_{}'.format(dfcount)]['MAP_name']='ABP'
                        #print(dftemp_0)
                        dfcount+=1
                for c in range(dfcount):
                    dftemp_final2=pd.concat([dftemp_final2,globals()['dftemp_{}'.format(c)]])
            except:
                pass

        except:
            pass


    MAP_CVP_total=dftemp_final2

    MAP_CVP_total=MAP_CVP_total.dropna(axis=0)

    MAP_CVP_total.drop_duplicates(inplace=True)
    MAP_CVP_total.sort_values(by=['Time'],axis=0,inplace=True)

    MAP_CVP_total.reset_index(inplace=True,drop=True)


    MAP_CVP_total['year']=MAP_CVP_total['Time'].str[:4]
    MAP_CVP_total['month']=MAP_CVP_total['Time'].str[5:7]
    MAP_CVP_total['day']=MAP_CVP_total['Time'].str[8:10]
    MAP_CVP_total['hour']=MAP_CVP_total['Time'].str[11:13]
    MAP_CVP_total['minute']=MAP_CVP_total['Time'].str[14:16]
    MAP_CVP_total['second']=MAP_CVP_total['Time'].str[17:19]
    MAP_CVP_total['year']=pd.to_numeric(MAP_CVP_total['year'])
    MAP_CVP_total['month']=pd.to_numeric(MAP_CVP_total['month'])
    MAP_CVP_total['day']=pd.to_numeric(MAP_CVP_total['day'])
    MAP_CVP_total['hour']=pd.to_numeric(MAP_CVP_total['hour'])
    MAP_CVP_total['minute']=pd.to_numeric(MAP_CVP_total['minute'])
    MAP_CVP_total['second']=pd.to_numeric(MAP_CVP_total['second'])
    MAP_CVP_total['second2']=(MAP_CVP_total['second']//5)*5


    MAP_CVP_total['timetime']=MAP_CVP_total['Time'].str[:17]+('0'+MAP_CVP_total['second2'].astype(str)).str[-2:]
    MAP_CVP_total['datetime']=pd.to_datetime(MAP_CVP_total['timetime'],format="%Y-%m-%d %H:%M:%S")


    MAP_CVP_total2=MAP_CVP_total[['datetime','MAP', 'CVP','MAP_name']]

    MAP_CVP_total2.drop_duplicates(inplace=True)
    MAP_CVP_total2.reset_index(inplace=True,drop=True)


    MAP_CVP_total2['MAP_drop']=0
    for j in range(len(MAP_CVP_total2)):
        if MAP_CVP_total2['MAP'][j]<=30:
            droptimelist=[]
            for k in range(-6,7):
                droptime=MAP_CVP_total2['datetime'][j]+datetime.timedelta(seconds=5*k)
                droptimelist.append(droptime)
            for k in range(len(droptimelist)):
                try:
                    MAP_CVP_total2.loc[MAP_CVP_total2['datetime'] == droptimelist[k], 'MAP_drop'] = 1
                except:
                    pass

    MAP_CVP_total2['CVP_drop']=0
    for j in range(len(MAP_CVP_total2)):
        if MAP_CVP_total2['CVP'][j]>=100:
            droptimelist=[]
            for k in range(-6,7):
                droptime=MAP_CVP_total2['datetime'][j]+datetime.timedelta(seconds=5*k)
                droptimelist.append(droptime)
            for k in range(len(droptimelist)):
                try:
                    MAP_CVP_total2.loc[MAP_CVP_total2['datetime'] == droptimelist[k], 'CVP_drop'] = 1
                except:
                    pass


    MAP_CVP_total2.to_csv("D:/postopdelirium_parameters/MAP_CVP_ABP/"+str(i)+'.csv')

# %%
MAP_avail_ART=[]
CVP_avail_ART=[]


for i in range(len(df)): 
    if True: 
        if df['op_type'][i]!=0 : 
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)
                CPB_on_time=get_CPB_on_time(i)
                CPB_off_time=get_CPB_off_time(i)

                total_anes_minus_CPB_time=(anes_end_time-anes_start_time).seconds-(CPB_off_time-CPB_on_time).seconds
                try:
                    TCA_start_time=get_TCA_start_time(i)
                    TCA_end_time=get_TCA_end_time(i)
                    total_anes_minus_TCA_time=(anes_end_time-anes_start_time).seconds-(TCA_end_time-TCA_start_time).seconds
                except:
                    total_anes_minus_TCA_time=(anes_end_time-anes_start_time).seconds

                MAP_CVP_df=pd.read_csv("D:/postopdelirium_parameters/MAP_CVP_ART/"+str(i)+'.csv')
                MAP_CVP_df['datetime']=pd.to_datetime(MAP_CVP_df['datetime'],format="%Y-%m-%d %H:%M:%S")
                MAP_count=0
                CVP_count=0
                for j in range(len(MAP_CVP_df)):

                    timestamp=MAP_CVP_df['datetime'][j]
                    if (timestamp>=anes_start_time and timestamp<=CPB_on_time) or (timestamp>=CPB_off_time and timestamp<=anes_end_time):
                        CVP_count+=1
                    try:
                        TCA_start_time=get_TCA_start_time(i)
                        TCA_end_time=get_TCA_end_time(i)
                        if (timestamp>=anes_start_time and timestamp<=TCA_start_time) or (timestamp>=TCA_end_time and timestamp<=anes_end_time):
                            MAP_count+=1
                    except:
                        if timestamp>=anes_start_time and timestamp<=anes_end_time:
                            MAP_count+=1

                MAP_avail_ART.append(MAP_count/(total_anes_minus_TCA_time//5))          
                CVP_avail_ART.append(CVP_count/(total_anes_minus_CPB_time//5))

            except:
                print(i,'error')  
                MAP_avail_ART.append(0)
                CVP_avail_ART.append(0)
        else:
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)

                total_anes_time=(anes_end_time-anes_start_time).seconds

                MAP_CVP_df=pd.read_csv("D:/postopdelirium_parameters/MAP_CVP_ART/"+str(i)+'.csv')
                MAP_CVP_df['datetime']=pd.to_datetime(MAP_CVP_df['datetime'],format="%Y-%m-%d %H:%M:%S")
                MAP_count=0
                CVP_count=0
                for j in range(len(MAP_CVP_df)):

                    timestamp=MAP_CVP_df['datetime'][j]
                    if timestamp>=anes_start_time and timestamp<=anes_end_time:
                        CVP_count+=1
                        MAP_count+=1

                MAP_avail_ART.append(MAP_count/(total_anes_time//5))          
                CVP_avail_ART.append(CVP_count/(total_anes_time//5))

            except:
                print(i,'error')  
                MAP_avail_ART.append(0)
                CVP_avail_ART.append(0)
    else:
        print(i,'====excluded=====')
        MAP_avail_ART.append(0)
        CVP_avail_ART.append(0)
df['MAP_avail_ART']=MAP_avail_ART
df['CVP_avail_ART']=CVP_avail_ART

# %%
MAP_avail_ABP=[]
CVP_avail_ABP=[]


for i in range(len(df)): 
    if True: 
        if df['op_type'][i]!=0 : 
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)
                CPB_on_time=get_CPB_on_time(i)
                CPB_off_time=get_CPB_off_time(i)

                total_anes_minus_CPB_time=(anes_end_time-anes_start_time).seconds-(CPB_off_time-CPB_on_time).seconds
                try:
                    TCA_start_time=get_TCA_start_time(i)
                    TCA_end_time=get_TCA_end_time(i)
                    total_anes_minus_TCA_time=(anes_end_time-anes_start_time).seconds-(TCA_end_time-TCA_start_time).seconds
                except:
                    total_anes_minus_TCA_time=(anes_end_time-anes_start_time).seconds

                MAP_CVP_df=pd.read_csv("D:/postopdelirium_parameters/MAP_CVP_ABP/"+str(i)+'.csv')
                MAP_CVP_df['datetime']=pd.to_datetime(MAP_CVP_df['datetime'],format="%Y-%m-%d %H:%M:%S")
                MAP_count=0
                CVP_count=0
                for j in range(len(MAP_CVP_df)):

                    timestamp=MAP_CVP_df['datetime'][j]
                    if (timestamp>=anes_start_time and timestamp<=CPB_on_time) or (timestamp>=CPB_off_time and timestamp<=anes_end_time):
                        CVP_count+=1
                    try:
                        TCA_start_time=get_TCA_start_time(i)
                        TCA_end_time=get_TCA_end_time(i)
                        if (timestamp>=anes_start_time and timestamp<=TCA_start_time) or (timestamp>=TCA_end_time and timestamp<=anes_end_time):
                            MAP_count+=1
                    except:
                        if timestamp>=anes_start_time and timestamp<=anes_end_time:
                            MAP_count+=1

                MAP_avail_ABP.append(MAP_count/(total_anes_minus_TCA_time//5))          
                CVP_avail_ABP.append(CVP_count/(total_anes_minus_CPB_time//5))
                #print(i)
            except:
                print(i,'error')  
                MAP_avail_ABP.append(0)
                CVP_avail_ABP.append(0)
        else:
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)

                total_anes_time=(anes_end_time-anes_start_time).seconds

                MAP_CVP_df=pd.read_csv("D:/postopdelirium_parameters/MAP_CVP_ABP/"+str(i)+'.csv')
                MAP_CVP_df['datetime']=pd.to_datetime(MAP_CVP_df['datetime'],format="%Y-%m-%d %H:%M:%S")
                MAP_count=0
                CVP_count=0
                for j in range(len(MAP_CVP_df)):

                    timestamp=MAP_CVP_df['datetime'][j]
                    if timestamp>=anes_start_time and timestamp<=anes_end_time:
                        CVP_count+=1
                        MAP_count+=1

                MAP_avail_ABP.append(MAP_count/(total_anes_time//5))          
                CVP_avail_ABP.append(CVP_count/(total_anes_time//5))
                #print(i)
            except:
                print(i,'error')  
                MAP_avail_ABP.append(0)
                CVP_avail_ABP.append(0)
    else:
        print(i,'====excluded=====')
        MAP_avail_ABP.append(0)
        CVP_avail_ABP.append(0)
df['MAP_avail_ABP']=MAP_avail_ABP
df['CVP_avail_ABP']=CVP_avail_ABP

# %%
MAP_type_list=[]

artcount=0
for i in range(len(df)):
    art_avail=df['MAP_avail_ART'][i]
    abp_avail=df['MAP_avail_ABP'][i]
    if art_avail!=0 or abp_avail!=0:
        if art_avail>=abp_avail:
            MAP_type='ART'
            artcount+=1
        else:
            MAP_type='ABP'
        MAP_type_list.append(MAP_type)
    else:
        MAP_type_list.append(np.nan)
        print(i,'====nan=====')

    
df['MAP_type']=MAP_type_list
print(artcount)

# %%
MAP_avail=[]
CVP_avail=[]
for i in range(len(df)):
    if df['MAP_type'][i]=='ART':
        MAP_avail.append(df['MAP_avail_ART'][i])
        CVP_avail.append(df['CVP_avail_ART'][i])
    else:
        MAP_avail.append(df['MAP_avail_ABP'][i])
        CVP_avail.append(df['CVP_avail_ABP'][i])
df['MAP_avail']=MAP_avail
df['CVP_avail']=CVP_avail

# %%
np.mean(MAP_avail)

# %%
plt.hist(MAP_avail)

# %%
for i in range(2007,2008): 
    if True: 
        if df['op_type'][i]!=0 : 
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)
                CPB_on_time=get_CPB_on_time(i)
                CPB_off_time=get_CPB_off_time(i)


                total_anes_minus_CPB_time=(anes_end_time-anes_start_time).seconds-(CPB_off_time-CPB_on_time).seconds
                try:
                    TCA_start_time=get_TCA_start_time(i)
                    TCA_end_time=get_TCA_end_time(i)
                    print(TCA_start_time)
                    print(TCA_end_time)
                    print((anes_end_time-anes_start_time).seconds)
                    print((TCA_end_time-TCA_start_time).seconds)
                    total_anes_minus_TCA_time=(anes_end_time-anes_start_time).seconds-(TCA_end_time-TCA_start_time).seconds
                    print(total_anes_minus_TCA_time)
                except:
                    total_anes_minus_TCA_time=(anes_end_time-anes_start_time).seconds

                MAP_CVP_df=pd.read_csv("D:/postopdelirium_parameters/MAP_CVP/"+str(i)+'.csv')
                MAP_CVP_df['datetime']=pd.to_datetime(MAP_CVP_df['datetime'],format="%Y-%m-%d %H:%M:%S")
                MAP_count=0
                CVP_count=0
                for j in range(len(MAP_CVP_df)):

                    timestamp=MAP_CVP_df['datetime'][j]
                    if (timestamp>=anes_start_time and timestamp<=CPB_on_time) or (timestamp>=CPB_off_time and timestamp<=anes_end_time):
                        CVP_count+=1
                    try:
                        TCA_start_time=get_TCA_start_time(i)
                        TCA_end_time=get_TCA_end_time(i)
                        if (timestamp>=anes_start_time and timestamp<=TCA_start_time) or (timestamp>=TCA_end_time and timestamp<=anes_end_time):
                            MAP_count+=1
                    except:
                        if timestamp>=anes_start_time and timestamp<=anes_end_time:
                            MAP_count+=1

            except:
                print(i,'error')  

        else:
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)

                total_anes_time=(anes_end_time-anes_start_time).seconds

                MAP_CVP_df=pd.read_csv("D:/postopdelirium_parameters/MAP_CVP/"+str(i)+'.csv')
                MAP_CVP_df['datetime']=pd.to_datetime(MAP_CVP_df['datetime'],format="%Y-%m-%d %H:%M:%S")
                MAP_count=0
                CVP_count=0
                for j in range(len(MAP_CVP_df)):

                    timestamp=MAP_CVP_df['datetime'][j]
                    if timestamp>=anes_start_time and timestamp<=anes_end_time:
                        CVP_count+=1
                        MAP_count+=1

            except:
                print(i,'error')  

    else:
        print(i,'====excluded=====')

# %%
np.mean(df['MAP_avail'])

# %%
np.mean(df['CVP_avail'])

# %%
plt.hist(MAP_avail)

# %%
plt.hist(CVP_avail)

# %%
##MAP_mean, MAP_CV, MAP_ARV
##MAP_duration_65, MAP_duration_100, MAP_auc_65, MAP_auc_100
##PP_mean
##PP_duration_60, PP_auc_60


MAP_mean_list=[]
MAP_CV_list=[]
MAP_ARV_list=[]
MAP_duration_65_list=[]
MAP_duration_100_list=[]
MAP_auc_65_list=[]
MAP_auc_100_list=[]
PP_mean_list=[]
PP_duration_60_list=[]
PP_auc_60_list=[]
CVP_duration_12_list=[]
CVP_auc_12_list=[]


for i in range(len(df)):
    if df['MAP_type'][i]=='ART':
        MAP_CVP_df=pd.read_csv("D:/postopdelirium_parameters/MAP_CVP_ART/"+str(i)+'.csv')
        MAP_CVP_df['datetime']=pd.to_datetime(MAP_CVP_df['datetime'],format="%Y-%m-%d %H:%M:%S")

        MAP_mean=np.nan
        MAP_CV=np.nan
        MAP_ARV=np.nan
        MAP_duration_65=np.nan
        MAP_duration_100=np.nan
        MAP_auc_65=np.nan
        MAP_auc_100=np.nan
        PP_mean=np.nan
        PP_duration_60=np.nan
        PP_auc_60=np.nan
        CVP_duration_12=np.nan
        CVP_auc_12=np.nan

        MAP_values=[]
        CVP_values=[]
        PP_values=[]

        if df['op_type'][i]!=0:

            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)
                CPB_on_time=get_CPB_on_time(i)
                CPB_off_time=get_CPB_off_time(i)


                try:
                    TCA_start_time=get_TCA_start_time(i)
                    TCA_end_time=get_TCA_end_time(i) 
                    for j in range(len(MAP_CVP_df)):          
                        timestamp=MAP_CVP_df['datetime'][j]
                        if (timestamp>=anes_start_time and timestamp<=TCA_start_time and MAP_CVP_df['MAP_drop'][j]==0) or (timestamp>=TCA_end_time and timestamp<=anes_end_time and MAP_CVP_df['MAP_drop'][j]==0):
                            MAP_values.append(MAP_CVP_df['MAP'][j].item())
                        if (timestamp>=anes_start_time and timestamp<=CPB_on_time and MAP_CVP_df['MAP_drop'][j]==0 and MAP_CVP_df['CVP_drop'][j]==0) or (timestamp>=CPB_off_time and timestamp<=anes_end_time and MAP_CVP_df['MAP_drop'][j]==0 and MAP_CVP_df['CVP_drop'][j]==0):
                            PP_values.append(MAP_CVP_df['MAP'][j].item()-MAP_CVP_df['CVP'][j].item())
                except:
                    for j in range(len(MAP_CVP_df)):          
                        timestamp=MAP_CVP_df['datetime'][j]
                        if timestamp>=anes_start_time and timestamp<=anes_end_time and MAP_CVP_df['MAP_drop'][j]==0:
                            MAP_values.append(MAP_CVP_df['MAP'][j].item())
                        if (timestamp>=anes_start_time and timestamp<=CPB_on_time and MAP_CVP_df['MAP_drop'][j]==0 and MAP_CVP_df['CVP_drop'][j]==0) or (timestamp>=CPB_off_time and timestamp<=anes_end_time and MAP_CVP_df['MAP_drop'][j]==0 and MAP_CVP_df['CVP_drop'][j]==0):
                            PP_values.append(MAP_CVP_df['MAP'][j].item()-MAP_CVP_df['CVP'][j].item())


                for j in range(len(MAP_CVP_df)):          
                    timestamp=MAP_CVP_df['datetime'][j]
                    if (timestamp>=anes_start_time and timestamp<=CPB_on_time and MAP_CVP_df['CVP_drop'][j]==0) or (timestamp>=CPB_off_time and timestamp<=anes_end_time and MAP_CVP_df['CVP_drop'][j]==0):
                        CVP_values.append(MAP_CVP_df['CVP'][j].item())

                if len(MAP_values)>0:
                    MAP_mean=np.mean(MAP_values)
                    MAP_CV=np.std(MAP_values)/np.mean(MAP_values)

                    real_variation=[]

                    for j in range(len(MAP_values)-1):
                        real_variation.append(abs(MAP_values[j+1]-MAP_values[j]))

                    MAP_ARV=np.mean(real_variation)

                    count_65=0
                    area_65=0
                    count_100=0
                    area_100=0
                    for j in range(len(MAP_values)):
                        if MAP_values[j]<65:
                            count_65+=1
                            area_65+=(65-MAP_values[j])
                        if MAP_values[j]>100:
                            count_100+=1
                            area_100+=(MAP_values[j]-100)


                    MAP_duration_65=count_65
                    MAP_duration_100=count_100
                    MAP_auc_65=area_65
                    MAP_auc_100=area_100

                if len(PP_values)>0:
                    PP_mean=np.mean(PP_values)

                    count_60=0
                    area_60=0
                    for j in range(len(PP_values)):
                        if PP_values[j]<60:
                            count_60+=1
                            area_60+=(60-PP_values[j])

                    PP_duration_60=count_60
                    PP_auc_60=area_60

                if len(CVP_values)>0:
                    count_12=0
                    area_12=0
                    for j in range(len(CVP_values)):
                        if CVP_values[j]>12:
                            count_12+=1
                            area_12+=(CVP_values[j]-12)

                    CVP_duration_12=count_12
                    CVP_auc_12=area_12

                MAP_mean_list.append(MAP_mean)
                MAP_CV_list.append(MAP_CV)
                MAP_ARV_list.append(MAP_ARV)
                MAP_duration_65_list.append(MAP_duration_65)
                MAP_duration_100_list.append(MAP_duration_100)
                MAP_auc_65_list.append(MAP_auc_65)
                MAP_auc_100_list.append(MAP_auc_100)
                PP_mean_list.append(PP_mean)
                PP_duration_60_list.append(PP_duration_60)
                PP_auc_60_list.append(PP_auc_60)
                CVP_duration_12_list.append(CVP_duration_12)
                CVP_auc_12_list.append(CVP_auc_12)


            except:
                print(i,'error')
                MAP_mean_list.append(MAP_mean)
                MAP_CV_list.append(MAP_CV)
                MAP_ARV_list.append(MAP_ARV)
                MAP_duration_65_list.append(MAP_duration_65)
                MAP_duration_100_list.append(MAP_duration_100)
                MAP_auc_65_list.append(MAP_auc_65)
                MAP_auc_100_list.append(MAP_auc_100)
                PP_mean_list.append(PP_mean)
                PP_duration_60_list.append(PP_duration_60)
                PP_auc_60_list.append(PP_auc_60)
                CVP_duration_12_list.append(CVP_duration_12)
                CVP_auc_12_list.append(CVP_auc_12)
        else:
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)

                for j in range(len(MAP_CVP_df)): 
                    timestamp=MAP_CVP_df['datetime'][j]
                    if timestamp>=anes_start_time and timestamp<=anes_end_time and MAP_CVP_df['MAP_drop'][j]==0:
                        MAP_values.append(MAP_CVP_df['MAP'][j].item())
                        PP_values.append(MAP_CVP_df['MAP'][j].item()-MAP_CVP_df['CVP'][j].item())

                for j in range(len(MAP_CVP_df)):          
                    timestamp=MAP_CVP_df['datetime'][j]
                    if timestamp>=anes_start_time and timestamp<=anes_end_time and MAP_CVP_df['CVP_drop'][j]==0:
                        CVP_values.append(MAP_CVP_df['CVP'][j].item())

                if len(MAP_values)>0:
                    MAP_mean=np.mean(MAP_values)
                    MAP_CV=np.std(MAP_values)/np.mean(MAP_values)

                    real_variation=[]

                    for j in range(len(MAP_values)-1):
                        real_variation.append(abs(MAP_values[j+1]-MAP_values[j]))

                    MAP_ARV=np.mean(real_variation)

                    count_65=0
                    area_65=0
                    count_100=0
                    area_100=0
                    for j in range(len(MAP_values)):
                        if MAP_values[j]<65:
                            count_65+=1
                            area_65+=(65-MAP_values[j])
                        if MAP_values[j]>100:
                            count_100+=1
                            area_100+=(MAP_values[j]-100)


                    MAP_duration_65=count_65
                    MAP_duration_100=count_100
                    MAP_auc_65=area_65
                    MAP_auc_100=area_100

                if len(PP_values)>0:
                    PP_mean=np.mean(PP_values)

                    count_60=0
                    area_60=0
                    for j in range(len(PP_values)):
                        if PP_values[j]<60:
                            count_60+=1
                            area_60+=(60-PP_values[j])

                    PP_duration_60=count_60
                    PP_auc_60=area_60

                if len(CVP_values)>0:
                    count_12=0
                    area_12=0
                    for j in range(len(CVP_values)):
                        if CVP_values[j]>12:
                            count_12+=1
                            area_12+=(CVP_values[j]-12)

                    CVP_duration_12=count_12
                    CVP_auc_12=area_12

                MAP_mean_list.append(MAP_mean)
                MAP_CV_list.append(MAP_CV)
                MAP_ARV_list.append(MAP_ARV)
                MAP_duration_65_list.append(MAP_duration_65)
                MAP_duration_100_list.append(MAP_duration_100)
                MAP_auc_65_list.append(MAP_auc_65)
                MAP_auc_100_list.append(MAP_auc_100)
                PP_mean_list.append(PP_mean)
                PP_duration_60_list.append(PP_duration_60)
                PP_auc_60_list.append(PP_auc_60)
                CVP_duration_12_list.append(CVP_duration_12)
                CVP_auc_12_list.append(CVP_auc_12)
                #print(i)


            except:
                print(i,'error')
                MAP_mean_list.append(MAP_mean)
                MAP_CV_list.append(MAP_CV)
                MAP_ARV_list.append(MAP_ARV)
                MAP_duration_65_list.append(MAP_duration_65)
                MAP_duration_100_list.append(MAP_duration_100)
                MAP_auc_65_list.append(MAP_auc_65)
                MAP_auc_100_list.append(MAP_auc_100)
                PP_mean_list.append(PP_mean)
                PP_duration_60_list.append(PP_duration_60)
                PP_auc_60_list.append(PP_auc_60)
                CVP_duration_12_list.append(CVP_duration_12)
                CVP_auc_12_list.append(CVP_auc_12)
                
    else:
        MAP_CVP_df=pd.read_csv("D:/postopdelirium_parameters/MAP_CVP_ABP/"+str(i)+'.csv')
        MAP_CVP_df['datetime']=pd.to_datetime(MAP_CVP_df['datetime'],format="%Y-%m-%d %H:%M:%S")

        MAP_mean=np.nan
        MAP_CV=np.nan
        MAP_ARV=np.nan
        MAP_duration_65=np.nan
        MAP_duration_100=np.nan
        MAP_auc_65=np.nan
        MAP_auc_100=np.nan
        PP_mean=np.nan
        PP_duration_60=np.nan
        PP_auc_60=np.nan
        CVP_duration_12=np.nan
        CVP_auc_12=np.nan

        MAP_values=[]
        CVP_values=[]
        PP_values=[]

        if df['op_type'][i]!=0:

            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)
                CPB_on_time=get_CPB_on_time(i)
                CPB_off_time=get_CPB_off_time(i)
                #op_end_time=get_op_end_time(i)
                #op_start_time=get_op_start_time(i)

                try:
                    TCA_start_time=get_TCA_start_time(i)
                    TCA_end_time=get_TCA_end_time(i) 
                    for j in range(len(MAP_CVP_df)):          
                        timestamp=MAP_CVP_df['datetime'][j]
                        if (timestamp>=anes_start_time and timestamp<=TCA_start_time and MAP_CVP_df['MAP_drop'][j]==0) or (timestamp>=TCA_end_time and timestamp<=anes_end_time and MAP_CVP_df['MAP_drop'][j]==0):
                            MAP_values.append(MAP_CVP_df['MAP'][j].item())
                        if (timestamp>=anes_start_time and timestamp<=CPB_on_time and MAP_CVP_df['MAP_drop'][j]==0 and MAP_CVP_df['CVP_drop'][j]==0) or (timestamp>=CPB_off_time and timestamp<=anes_end_time and MAP_CVP_df['MAP_drop'][j]==0 and MAP_CVP_df['CVP_drop'][j]==0):
                            PP_values.append(MAP_CVP_df['MAP'][j].item()-MAP_CVP_df['CVP'][j].item())
                except:
                    for j in range(len(MAP_CVP_df)):          
                        timestamp=MAP_CVP_df['datetime'][j]
                        if timestamp>=anes_start_time and timestamp<=anes_end_time and MAP_CVP_df['MAP_drop'][j]==0:
                            MAP_values.append(MAP_CVP_df['MAP'][j].item())
                        if (timestamp>=anes_start_time and timestamp<=CPB_on_time and MAP_CVP_df['MAP_drop'][j]==0 and MAP_CVP_df['CVP_drop'][j]==0) or (timestamp>=CPB_off_time and timestamp<=anes_end_time and MAP_CVP_df['MAP_drop'][j]==0 and MAP_CVP_df['CVP_drop'][j]==0):
                            PP_values.append(MAP_CVP_df['MAP'][j].item()-MAP_CVP_df['CVP'][j].item())


                for j in range(len(MAP_CVP_df)):          
                    timestamp=MAP_CVP_df['datetime'][j]
                    if (timestamp>=anes_start_time and timestamp<=CPB_on_time and MAP_CVP_df['CVP_drop'][j]==0) or (timestamp>=CPB_off_time and timestamp<=anes_end_time and MAP_CVP_df['CVP_drop'][j]==0):
                        CVP_values.append(MAP_CVP_df['CVP'][j].item())

                if len(MAP_values)>0:
                    MAP_mean=np.mean(MAP_values)
                    MAP_CV=np.std(MAP_values)/np.mean(MAP_values)

                    real_variation=[]

                    for j in range(len(MAP_values)-1):
                        real_variation.append(abs(MAP_values[j+1]-MAP_values[j]))

                    MAP_ARV=np.mean(real_variation)

                    count_65=0
                    area_65=0
                    count_100=0
                    area_100=0
                    for j in range(len(MAP_values)):
                        if MAP_values[j]<65:
                            count_65+=1
                            area_65+=(65-MAP_values[j])
                        if MAP_values[j]>100:
                            count_100+=1
                            area_100+=(MAP_values[j]-100)


                    MAP_duration_65=count_65
                    MAP_duration_100=count_100
                    MAP_auc_65=area_65
                    MAP_auc_100=area_100

                if len(PP_values)>0:
                    PP_mean=np.mean(PP_values)

                    count_60=0
                    area_60=0
                    for j in range(len(PP_values)):
                        if PP_values[j]<60:
                            count_60+=1
                            area_60+=(60-PP_values[j])

                    PP_duration_60=count_60
                    PP_auc_60=area_60

                if len(CVP_values)>0:
                    count_12=0
                    area_12=0
                    for j in range(len(CVP_values)):
                        if CVP_values[j]>12:
                            count_12+=1
                            area_12+=(CVP_values[j]-12)

                    CVP_duration_12=count_12
                    CVP_auc_12=area_12

                MAP_mean_list.append(MAP_mean)
                MAP_CV_list.append(MAP_CV)
                MAP_ARV_list.append(MAP_ARV)
                MAP_duration_65_list.append(MAP_duration_65)
                MAP_duration_100_list.append(MAP_duration_100)
                MAP_auc_65_list.append(MAP_auc_65)
                MAP_auc_100_list.append(MAP_auc_100)
                PP_mean_list.append(PP_mean)
                PP_duration_60_list.append(PP_duration_60)
                PP_auc_60_list.append(PP_auc_60)
                CVP_duration_12_list.append(CVP_duration_12)
                CVP_auc_12_list.append(CVP_auc_12)
                #print(i)


            except:
                print(i,'error')
                MAP_mean_list.append(MAP_mean)
                MAP_CV_list.append(MAP_CV)
                MAP_ARV_list.append(MAP_ARV)
                MAP_duration_65_list.append(MAP_duration_65)
                MAP_duration_100_list.append(MAP_duration_100)
                MAP_auc_65_list.append(MAP_auc_65)
                MAP_auc_100_list.append(MAP_auc_100)
                PP_mean_list.append(PP_mean)
                PP_duration_60_list.append(PP_duration_60)
                PP_auc_60_list.append(PP_auc_60)
                CVP_duration_12_list.append(CVP_duration_12)
                CVP_auc_12_list.append(CVP_auc_12)
        else:
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)

                for j in range(len(MAP_CVP_df)): 
                    timestamp=MAP_CVP_df['datetime'][j]
                    if timestamp>=anes_start_time and timestamp<=anes_end_time and MAP_CVP_df['MAP_drop'][j]==0:
                        MAP_values.append(MAP_CVP_df['MAP'][j].item())
                        PP_values.append(MAP_CVP_df['MAP'][j].item()-MAP_CVP_df['CVP'][j].item())

                for j in range(len(MAP_CVP_df)):          
                    timestamp=MAP_CVP_df['datetime'][j]
                    if timestamp>=anes_start_time and timestamp<=anes_end_time and MAP_CVP_df['CVP_drop'][j]==0:
                        CVP_values.append(MAP_CVP_df['CVP'][j].item())

                if len(MAP_values)>0:
                    MAP_mean=np.mean(MAP_values)
                    MAP_CV=np.std(MAP_values)/np.mean(MAP_values)

                    real_variation=[]

                    for j in range(len(MAP_values)-1):
                        real_variation.append(abs(MAP_values[j+1]-MAP_values[j]))

                    MAP_ARV=np.mean(real_variation)

                    count_65=0
                    area_65=0
                    count_100=0
                    area_100=0
                    for j in range(len(MAP_values)):
                        if MAP_values[j]<65:
                            count_65+=1
                            area_65+=(65-MAP_values[j])
                        if MAP_values[j]>100:
                            count_100+=1
                            area_100+=(MAP_values[j]-100)


                    MAP_duration_65=count_65
                    MAP_duration_100=count_100
                    MAP_auc_65=area_65
                    MAP_auc_100=area_100

                if len(PP_values)>0:
                    PP_mean=np.mean(PP_values)

                    count_60=0
                    area_60=0
                    for j in range(len(PP_values)):
                        if PP_values[j]<60:
                            count_60+=1
                            area_60+=(60-PP_values[j])

                    PP_duration_60=count_60
                    PP_auc_60=area_60

                if len(CVP_values)>0:
                    count_12=0
                    area_12=0
                    for j in range(len(CVP_values)):
                        if CVP_values[j]>12:
                            count_12+=1
                            area_12+=(CVP_values[j]-12)

                    CVP_duration_12=count_12
                    CVP_auc_12=area_12

                MAP_mean_list.append(MAP_mean)
                MAP_CV_list.append(MAP_CV)
                MAP_ARV_list.append(MAP_ARV)
                MAP_duration_65_list.append(MAP_duration_65)
                MAP_duration_100_list.append(MAP_duration_100)
                MAP_auc_65_list.append(MAP_auc_65)
                MAP_auc_100_list.append(MAP_auc_100)
                PP_mean_list.append(PP_mean)
                PP_duration_60_list.append(PP_duration_60)
                PP_auc_60_list.append(PP_auc_60)
                CVP_duration_12_list.append(CVP_duration_12)
                CVP_auc_12_list.append(CVP_auc_12)

            except:
                print(i,'error')
                MAP_mean_list.append(MAP_mean)
                MAP_CV_list.append(MAP_CV)
                MAP_ARV_list.append(MAP_ARV)
                MAP_duration_65_list.append(MAP_duration_65)
                MAP_duration_100_list.append(MAP_duration_100)
                MAP_auc_65_list.append(MAP_auc_65)
                MAP_auc_100_list.append(MAP_auc_100)
                PP_mean_list.append(PP_mean)
                PP_duration_60_list.append(PP_duration_60)
                PP_auc_60_list.append(PP_auc_60)
                CVP_duration_12_list.append(CVP_duration_12)
                CVP_auc_12_list.append(CVP_auc_12)
        

        
        
df['MAP_mean_list']=MAP_mean_list
df['MAP_CV_list']=MAP_CV_list
df['MAP_ARV_list']=MAP_ARV_list
df['MAP_duration_65_list']=MAP_duration_65_list
df['MAP_duration_100_list']=MAP_duration_100_list
df['MAP_auc_65_list']=MAP_auc_65_list
df['MAP_auc_100_list']=MAP_auc_100_list
df['PP_mean_list']=PP_mean_list
df['PP_duration_60_list']=PP_duration_60_list
df['PP_auc_60_list']=PP_auc_60_list
df['CVP_duration_12_list']=CVP_duration_12_list
df['CVP_auc_12_list']=CVP_auc_12_list

# %%
df.to_csv('postop5cha_temp3.csv')

# %%
aa=list(df.columns)[205:]
for i in aa:
    aaa=df[i]
    try:
        print(i)
        plt.hist(aaa)
        plt.show()
    except:
        print(i)

# %%
##HR_CV,HR_ARV
##HR_duration_40, HR_auc_40


for i in range(len(df)):
    if i<1915:
        a=df['no'][i]-1
        if a>=0 and a<=199:
            folder="D:/postopdelirium_csv/0001_0200/0001_0200/"
        elif a>=200 and a<=399:
            folder="D:/postopdelirium_csv/0201_0400/0201_0400/"
        elif a>=400 and a<=599:
            folder="D:/postopdelirium_csv/0401_0600/0401_0600/"
        elif a>=600 and a<=799:
            folder="D:/postopdelirium_csv/0601_0800/0601_0800/"
        elif a>=800 and a<=825:
            folder="D:/postopdelirium_csv/0801_/0801_/"    
        elif a>=826 and a<=999:
            folder="D:/postopdelirium_csv/0827_1000/0827_1000/"
        elif a>=1000 and a<=1199:
            folder="D:/postopdelirium_csv/1001_1200/1001_1200/"
        elif a>=1200 and a<=1399:
            folder="D:/postopdelirium_csv/1201_1400/1201_1400/"
        elif a>=1400 and a<=1649:
            folder="D:/postopdelirium_csv/1401_1650/1401_1650/"
        elif a>=1650 and a<=1799:
            folder="D:/postopdelirium_csv/1651_1800/1651_1800/"
        else:
            folder="D:/postopdelirium_csv/1801_1968/1801_1968/"
    else:
        folder="E:/Workspace/Data/Postopdelirium/postopdelirium_validation_csv/delirium_validation_vitaldb_1_210/"

        
        
    HR_total=pd.DataFrame(columns=['Time','HR'])
    dftemp_final1=pd.DataFrame(columns=['Time','HR'])

    if a!=180: 
        for filefile in ['파일이름_01','파일이름_02','파일이름_03','파일이름_04','파일이름_05','파일이름_06','파일이름_07','파일이름_08']:      
            try:
                dat=pd.read_csv(findfile(df[filefile][i],folder))
                try:
                    dat['Intellivue/ECG_HR']
                    datcolumns=list(dat.columns)
                    hr_columns=[]
                    for c in datcolumns:
                        if c[:17]=='Intellivue/ECG_HR':
                            hr_columns.append(c)
                    dfcount=0
                    for c in hr_columns:
                        globals()['dftemp_{}'.format(dfcount)]=dat[['Time',c]]
                        globals()['dftemp_{}'.format(dfcount)].columns=['Time','HR']
                        globals()['dftemp_{}'.format(dfcount)]=globals()['dftemp_{}'.format(dfcount)].dropna(axis=0)

                        dfcount+=1
                    for c in range(dfcount):
                        dftemp_final1=pd.concat([dftemp_final1,globals()['dftemp_{}'.format(c)]])

                except:
                    pass   
            except:
                pass
    else:
        for filefile in ['파일이름_01','파일이름_02','파일이름_03','파일이름_04']:      
            try:
                dat=pd.read_csv(findfile(df[filefile][i],folder))
                try:
                    dat['Intellivue/ECG_HR']
                    datcolumns=list(dat.columns)
                    hr_columns=[]
                    for c in datcolumns:
                        if c[:17]=='Intellivue/ECG_HR':
                            hr_columns.append(c)
                    dfcount=0
                    for c in hr_columns:
                        globals()['dftemp_{}'.format(dfcount)]=dat[['Time',c]]
                        globals()['dftemp_{}'.format(dfcount)].columns=['Time','HR']
                        globals()['dftemp_{}'.format(dfcount)]=globals()['dftemp_{}'.format(dfcount)].dropna(axis=0)
                        #print(dftemp_0)
                        dfcount+=1
                    for c in range(dfcount):
                        dftemp_final1=pd.concat([dftemp_final1,globals()['dftemp_{}'.format(c)]])

                except:
                    pass   
            except:
                pass

    HR_total=dftemp_final1
    HR_total=HR_total.dropna(axis=0)

    HR_total.drop_duplicates(inplace=True)
    HR_total.sort_values(by=['Time'],axis=0,inplace=True)

    HR_total.reset_index(inplace=True,drop=True)



    HR_total['year']=HR_total['Time'].str[:4]
    HR_total['month']=HR_total['Time'].str[5:7]
    HR_total['day']=HR_total['Time'].str[8:10]
    HR_total['hour']=HR_total['Time'].str[11:13]
    HR_total['minute']=HR_total['Time'].str[14:16]
    HR_total['second']=HR_total['Time'].str[17:19]
    HR_total['year']=pd.to_numeric(HR_total['year'])
    HR_total['month']=pd.to_numeric(HR_total['month'])
    HR_total['day']=pd.to_numeric(HR_total['day'])
    HR_total['hour']=pd.to_numeric(HR_total['hour'])
    HR_total['minute']=pd.to_numeric(HR_total['minute'])
    HR_total['second']=pd.to_numeric(HR_total['second'])
    HR_total['second2']=(HR_total['second']//5)*5


    HR_total['timetime']=HR_total['Time'].str[:17]+('0'+HR_total['second2'].astype(str)).str[-2:]
    HR_total['datetime']=pd.to_datetime(HR_total['timetime'],format="%Y-%m-%d %H:%M:%S")


    HR_total2=HR_total[['datetime','HR']]
    HR_total3=HR_total2[HR_total2['HR']!=0]
    HR_total3.drop_duplicates(inplace=True)
    HR_total3.reset_index(inplace=True,drop=True)


    HR_total3.to_csv("D:/postopdelirium_parameters/HR/"+str(i)+'.csv')

# %%
HR_avail=[]

    
for i in range(len(df)):
    if True: 
        if df['op_type'][i]!=0:
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)
                CPB_on_time=get_CPB_on_time(i)
                CPB_off_time=get_CPB_off_time(i)

                total_anes_minus_CPB_time=(anes_end_time-anes_start_time).seconds-(CPB_off_time-CPB_on_time).seconds

                HR_df=pd.read_csv("D:/postopdelirium_parameters/HR/"+str(i)+'.csv')
                HR_df['datetime']=pd.to_datetime(HR_df['datetime'],format="%Y-%m-%d %H:%M:%S")
                count=0

                for j in range(len(HR_df)):

                    timestamp=HR_df['datetime'][j]
                    if (timestamp>=anes_start_time and timestamp<=CPB_on_time) or (timestamp>=CPB_off_time and timestamp<=anes_end_time):
                        count+=1

                HR_avail.append(count/(total_anes_minus_CPB_time//5))          

            except:
                print(i,'error')  
                HR_avail.append(0)
        else:
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)


                total_anes_time=(anes_end_time-anes_start_time).seconds

                HR_df=pd.read_csv("D:/postopdelirium_parameters/HR/"+str(i)+'.csv')
                HR_df['datetime']=pd.to_datetime(HR_df['datetime'],format="%Y-%m-%d %H:%M:%S")
                count=0
                #print('1')
                for j in range(len(HR_df)):

                    timestamp=HR_df['datetime'][j]
                    if timestamp>=anes_start_time and timestamp<=anes_end_time:
                        count+=1

                HR_avail.append(count/(total_anes_time//5))          

            except:
                print(i,'error')  
                HR_avail.append(0)
    else:
        print(i,'===excluded====')
        HR_avail.append(0)

df['HR_avail']=HR_avail

# %%
plt.hist(HR_avail)

# %%
np.mean(HR_avail)

# %%
##HR_CV,HR_ARV
##HR_duration_40, HR_duration_110


HR_CV_list=[]
HR_ARV_list=[]
HR_duration_40_list=[]
HR_duration_110_list=[]


for i in range(len(df)):
    if True:
        HR_df=pd.read_csv("D:/postopdelirium_parameters/HR/"+str(i)+'.csv')
        HR_df['datetime']=pd.to_datetime(HR_df['datetime'],format="%Y-%m-%d %H:%M:%S")

        HR_CV=np.nan
        HR_ARV=np.nan
        HR_duration_40=np.nan
        HR_duration_110=np.nan

        HR_values=[]

        if df['op_type'][i]!=0:
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)
                CPB_on_time=get_CPB_on_time(i)
                CPB_off_time=get_CPB_off_time(i)


                for j in range(len(HR_df)):          
                    timestamp=HR_df['datetime'][j]
                    if (timestamp>=anes_start_time and timestamp<=CPB_on_time) or (timestamp>=CPB_off_time and timestamp<=anes_end_time):
                        HR_values.append(HR_df['HR'][j].item())

                if len(HR_values)>0:
                    HR_CV=np.std(HR_values)/np.mean(HR_values)

                    real_variation=[]

                    for j in range(len(HR_values)-1):
                        real_variation.append(abs(HR_values[j+1]-HR_values[j]))

                    HR_ARV=np.mean(real_variation)

                    count_40=0
                    count_110=0

                    for j in range(len(HR_values)):
                        if HR_values[j]<40:
                            count_40+=1
                        if HR_values[j]>110:
                            count_110+=1


                    HR_duration_40=count_40
                    HR_duration_110=count_110



                HR_CV_list.append(HR_CV)
                HR_ARV_list.append(HR_ARV)
                HR_duration_40_list.append(HR_duration_40)
                HR_duration_110_list.append(HR_duration_110)


            except:
                print(i,'error')
                HR_CV_list.append(HR_CV)
                HR_ARV_list.append(HR_ARV)
                HR_duration_40_list.append(HR_duration_40)
                HR_duration_110_list.append(HR_duration_110)
        else:
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)


                for j in range(len(HR_df)):          
                    timestamp=HR_df['datetime'][j]
                    if timestamp>=anes_start_time and timestamp<=anes_end_time:
                        HR_values.append(HR_df['HR'][j].item())

                if len(HR_values)>0:
                    HR_CV=np.std(HR_values)/np.mean(HR_values)

                    real_variation=[]

                    for j in range(len(HR_values)-1):
                        real_variation.append(abs(HR_values[j+1]-HR_values[j]))

                    HR_ARV=np.mean(real_variation)

                    count_40=0
                    count_110=0

                    for j in range(len(HR_values)):
                        if HR_values[j]<40:
                            count_40+=1
                        if HR_values[j]>110:
                            count_110+=1


                    HR_duration_40=count_40
                    HR_duration_110=count_110



                HR_CV_list.append(HR_CV)
                HR_ARV_list.append(HR_ARV)
                HR_duration_40_list.append(HR_duration_40)
                HR_duration_110_list.append(HR_duration_110)


            except:
                print(i,'error')
                HR_CV_list.append(HR_CV)
                HR_ARV_list.append(HR_ARV)
                HR_duration_40_list.append(HR_duration_40)
                HR_duration_110_list.append(HR_duration_110)
    else:
        print(i,'===excluded====')
        
        HR_CV=np.nan
        HR_ARV=np.nan
        HR_duration_40=np.nan
        HR_duration_110=np.nan
        
        
        HR_CV_list.append(HR_CV)
        HR_ARV_list.append(HR_ARV)
        HR_duration_40_list.append(HR_duration_40)
        HR_duration_110_list.append(HR_duration_110)
    
        
        
df['HR_CV_list']=HR_CV_list
df['HR_ARV_list']=HR_ARV_list
df['HR_duration_40_list']=HR_duration_40_list
df['HR_duration_110_list']=HR_duration_110_list

# %%
df.to_csv('postop4cha_temp6.csv')

# %%
##mPAP_duration_20, mPAP_auc_20


for i in range(len(df)):
    if i<1915:
        a=df['no'][i]-1
        if a>=0 and a<=199:
            folder="D:/postopdelirium_csv/0001_0200/0001_0200/"
        elif a>=200 and a<=399:
            folder="D:/postopdelirium_csv/0201_0400/0201_0400/"
        elif a>=400 and a<=599:
            folder="D:/postopdelirium_csv/0401_0600/0401_0600/"
        elif a>=600 and a<=799:
            folder="D:/postopdelirium_csv/0601_0800/0601_0800/"
        elif a>=800 and a<=825:
            folder="D:/postopdelirium_csv/0801_/0801_/"    
        elif a>=826 and a<=999:
            folder="D:/postopdelirium_csv/0827_1000/0827_1000/"
        elif a>=1000 and a<=1199:
            folder="D:/postopdelirium_csv/1001_1200/1001_1200/"
        elif a>=1200 and a<=1399:
            folder="D:/postopdelirium_csv/1201_1400/1201_1400/"
        elif a>=1400 and a<=1649:
            folder="D:/postopdelirium_csv/1401_1650/1401_1650/"
        elif a>=1650 and a<=1799:
            folder="D:/postopdelirium_csv/1651_1800/1651_1800/"
        else:
            folder="D:/postopdelirium_csv/1801_1968/1801_1968/"
    else:
        folder="E:/Workspace/Data/Postopdelirium/postopdelirium_validation_csv/delirium_validation_vitaldb_1_210/"

    mPAP_total=pd.DataFrame(columns=['Time','mPAP'])
    
    dftemp_final1=pd.DataFrame(columns=['Time','mPAP'])
    
    for filefile in ['파일이름_01','파일이름_02','파일이름_03','파일이름_04','파일이름_05','파일이름_06','파일이름_07','파일이름_08']:      
        try:
            dat=pd.read_csv(findfile(df[filefile][i],folder))
            try:
                dat['Intellivue/PAP_MEAN']
                datcolumns=list(dat.columns)
                pap_columns=[]
                for c in datcolumns:
                    if c[:19]=='Intellivue/PAP_MEAN':
                        pap_columns.append(c)
                dfcount=0
                for c in pap_columns:
                    globals()['dftemp_{}'.format(dfcount)]=dat[['Time',c]]
                    globals()['dftemp_{}'.format(dfcount)].columns=['Time','mPAP']
                    globals()['dftemp_{}'.format(dfcount)]=globals()['dftemp_{}'.format(dfcount)].dropna(axis=0)

                    dfcount+=1
                for c in range(dfcount):
                    dftemp_final1=pd.concat([dftemp_final1,globals()['dftemp_{}'.format(c)]])

            except:
                pass   
        except:
            pass


    mPAP_total=dftemp_final1

    mPAP_total.drop_duplicates(inplace=True)
    mPAP_total.sort_values(by=['Time'],axis=0,inplace=True)

    mPAP_total.reset_index(inplace=True,drop=True)



    mPAP_total['year']=mPAP_total['Time'].str[:4]
    mPAP_total['month']=mPAP_total['Time'].str[5:7]
    mPAP_total['day']=mPAP_total['Time'].str[8:10]
    mPAP_total['hour']=mPAP_total['Time'].str[11:13]
    mPAP_total['minute']=mPAP_total['Time'].str[14:16]
    mPAP_total['second']=mPAP_total['Time'].str[17:19]
    mPAP_total['year']=pd.to_numeric(mPAP_total['year'])
    mPAP_total['month']=pd.to_numeric(mPAP_total['month'])
    mPAP_total['day']=pd.to_numeric(mPAP_total['day'])
    mPAP_total['hour']=pd.to_numeric(mPAP_total['hour'])
    mPAP_total['minute']=pd.to_numeric(mPAP_total['minute'])
    mPAP_total['second']=pd.to_numeric(mPAP_total['second'])
    mPAP_total['second2']=(mPAP_total['second']//5)*5


    mPAP_total['timetime']=mPAP_total['Time'].str[:17]+('0'+mPAP_total['second2'].astype(str)).str[-2:]
    mPAP_total['datetime']=pd.to_datetime(mPAP_total['timetime'],format="%Y-%m-%d %H:%M:%S")


    mPAP_total2=mPAP_total[['datetime','mPAP']]

    mPAP_total2['mPAP_drop']=0
    for j in range(len(mPAP_total2)):
        if mPAP_total2['mPAP'][j]>=100:
            droptimelist=[]
            for k in range(-6,7):
                droptime=mPAP_total2['datetime'][j]+datetime.timedelta(seconds=5*k)
                droptimelist.append(droptime)
            for k in range(len(droptimelist)):
                try:
                    mPAP_total2.loc[mPAP_total2['datetime'] == droptimelist[k], 'mPAP_drop'] = 1
                except:
                    pass




    mPAP_total2.drop_duplicates(inplace=True)
    mPAP_total2.reset_index(inplace=True,drop=True)




    mPAP_total2.to_csv("D:/postopdelirium_parameters/mPAP/"+str(i)+'.csv')

# %%
df.iloc[2118:2119]

# %%
mPAP_avail=[]


for i in range(len(df)):
    if True: 
        if df['op_type'][i]!=0:
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)
                CPB_on_time=get_CPB_on_time(i)
                CPB_off_time=get_CPB_off_time(i)

                total_anes_minus_CPB_time=(anes_end_time-anes_start_time).seconds-(CPB_off_time-CPB_on_time).seconds

                mPAP_df=pd.read_csv("D:/postopdelirium_parameters/mPAP/"+str(i)+'.csv')
                mPAP_df['datetime']=pd.to_datetime(mPAP_df['datetime'],format="%Y-%m-%d %H:%M:%S")
                count=0

                for j in range(len(mPAP_df)):

                    timestamp=mPAP_df['datetime'][j]
                    if (timestamp>=anes_start_time and timestamp<=CPB_on_time) or (timestamp>=CPB_off_time and timestamp<=anes_end_time):
                        count+=1

                mPAP_avail.append(count/(total_anes_minus_CPB_time//5))          

            except:
                print(i,'error')  
                mPAP_avail.append(0)
        else:
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)


                total_anes_time=(anes_end_time-anes_start_time).seconds

                mPAP_df=pd.read_csv("D:/postopdelirium_parameters/mPAP/"+str(i)+'.csv')
                mPAP_df['datetime']=pd.to_datetime(mPAP_df['datetime'],format="%Y-%m-%d %H:%M:%S")
                count=0

                for j in range(len(mPAP_df)):

                    timestamp=mPAP_df['datetime'][j]
                    if timestamp>=anes_start_time and timestamp<=anes_end_time:
                        count+=1

                mPAP_avail.append(count/(total_anes_time//5))          

                #print(i)
            except:
                print(i,'error')  
                mPAP_avail.append(0)
    else:
        print(i,'===excluded====')
        mPAP_avail.append(0)

df['mPAP_avail']=mPAP_avail

# %%
plt.hist(mPAP_avail)

# %%
##mPAP_duration_20, mPAP_auc_20


mPAP_duration_20_list=[]
mPAP_auc_20_list=[]


for i in range(len(df)):
    if True: 
        mPAP_df=pd.read_csv("D:/postopdelirium_parameters/mPAP/"+str(i)+'.csv')
        mPAP_df['datetime']=pd.to_datetime(mPAP_df['datetime'],format="%Y-%m-%d %H:%M:%S")

        mPAP_duration_20=np.nan
        mPAP_auc_20=np.nan


        mPAP_values=[]
        if df['op_type'][i]!=0:
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)
                CPB_on_time=get_CPB_on_time(i)
                CPB_off_time=get_CPB_off_time(i)


                for j in range(len(mPAP_df)):          
                    timestamp=mPAP_df['datetime'][j]
                    if (timestamp>=anes_start_time and timestamp<=CPB_on_time and mPAP_df['mPAP_drop'][j]==0) or (timestamp>=CPB_off_time and timestamp<=anes_end_time and mPAP_df['mPAP_drop'][j]==0):
                        mPAP_values.append(mPAP_df['mPAP'][j].item())

                if len(mPAP_values)>0:

                    count_20=0
                    area_20=0

                    for j in range(len(mPAP_values)):
                        if mPAP_values[j]>20:
                            count_20+=1
                            area_20+=(mPAP_values[j]-20)


                    mPAP_duration_20=count_20
                    mPAP_auc_20=area_20



                mPAP_duration_20_list.append(mPAP_duration_20)
                mPAP_auc_20_list.append(mPAP_auc_20)

                #print(i)


            except:
                print(i,'error')
                mPAP_duration_20_list.append(mPAP_duration_20)
                mPAP_auc_20_list.append(mPAP_auc_20)
        else:
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)


                for j in range(len(mPAP_df)):          
                    timestamp=mPAP_df['datetime'][j]
                    if timestamp>=anes_start_time and timestamp<=anes_end_time and mPAP_df['mPAP_drop'][j]==0:
                        mPAP_values.append(mPAP_df['mPAP'][j].item())

                if len(mPAP_values)>0:

                    count_20=0
                    area_20=0

                    for j in range(len(mPAP_values)):
                        if mPAP_values[j]>20:
                            count_20+=1
                            area_20+=(mPAP_values[j]-20)


                    mPAP_duration_20=count_20
                    mPAP_auc_20=area_20



                mPAP_duration_20_list.append(mPAP_duration_20)
                mPAP_auc_20_list.append(mPAP_auc_20)


            except:
                print(i,'error')
                mPAP_duration_20_list.append(mPAP_duration_20)
                mPAP_auc_20_list.append(mPAP_auc_20)
                
    else:
        print(i,'===excluded===')
        
        mPAP_duration_20=np.nan
        mPAP_auc_20=np.nan
        
        mPAP_duration_20_list.append(mPAP_duration_20)
        mPAP_auc_20_list.append(mPAP_auc_20)

        
        
df['mPAP_duration_20_list']=mPAP_duration_20_list
df['mPAP_auc_20_list']=mPAP_auc_20_list

# %%
df.to_csv('postop4cha_temp7.csv')

# %%
##CI_mean,CI_duration_2,CI_auc_2


for i in range(len(df)):
    if i<1915:
        a=df['no'][i]-1
        if a>=0 and a<=199:
            folder="D:/postopdelirium_csv/0001_0200/0001_0200/"
        elif a>=200 and a<=399:
            folder="D:/postopdelirium_csv/0201_0400/0201_0400/"
        elif a>=400 and a<=599:
            folder="D:/postopdelirium_csv/0401_0600/0401_0600/"
        elif a>=600 and a<=799:
            folder="D:/postopdelirium_csv/0601_0800/0601_0800/"
        elif a>=800 and a<=825:
            folder="D:/postopdelirium_csv/0801_/0801_/"    
        elif a>=826 and a<=999:
            folder="D:/postopdelirium_csv/0827_1000/0827_1000/"
        elif a>=1000 and a<=1199:
            folder="D:/postopdelirium_csv/1001_1200/1001_1200/"
        elif a>=1200 and a<=1399:
            folder="D:/postopdelirium_csv/1201_1400/1201_1400/"
        elif a>=1400 and a<=1649:
            folder="D:/postopdelirium_csv/1401_1650/1401_1650/"
        elif a>=1650 and a<=1799:
            folder="D:/postopdelirium_csv/1651_1800/1651_1800/"
        else:
            folder="D:/postopdelirium_csv/1801_1968/1801_1968/"
    else:
        folder="E:/Workspace/Data/Postopdelirium/postopdelirium_validation_csv/delirium_validation_vitaldb_1_210/"

    
    CI_total=pd.DataFrame(columns=['Time','CI'])
    dftemp_final1=pd.DataFrame(columns=['Time','CI'])

    for filefile in ['파일이름_01','파일이름_02','파일이름_03','파일이름_04','파일이름_05','파일이름_06','파일이름_07','파일이름_08']:      
        try:
            dat=pd.read_csv(findfile(df[filefile][i],folder))
            try:
                dat['Hemosphere/CI']

                datcolumns=list(dat.columns)
                ci_columns=[]
                for c in datcolumns:
                    if c[:13]=='Hemosphere/CI' and c[:18]!='Hemosphere/CI_STAT':
                        ci_columns.append(c)
                dfcount=0
                for c in ci_columns:
                    globals()['dftemp_{}'.format(dfcount)]=dat[['Time',c]]
                    globals()['dftemp_{}'.format(dfcount)].columns=['Time','CI']
                    globals()['dftemp_{}'.format(dfcount)]=globals()['dftemp_{}'.format(dfcount)].dropna(axis=0)
                    #print(dftemp_0)
                    dfcount+=1
                
                for c in range(dfcount):
                    dftemp_final1=pd.concat([dftemp_final1,globals()['dftemp_{}'.format(c)]])
                
            except:
                pass   
        except:
            pass

    CI_total=dftemp_final1
    CI_total=CI_total.dropna(axis=0)

    CI_total.drop_duplicates(inplace=True)
    CI_total.sort_values(by=['Time'],axis=0,inplace=True)

    CI_total.reset_index(inplace=True,drop=True)

    CI_total['year']=CI_total['Time'].str[:4]
    CI_total['month']=CI_total['Time'].str[5:7]
    CI_total['day']=CI_total['Time'].str[8:10]
    CI_total['hour']=CI_total['Time'].str[11:13]
    CI_total['minute']=CI_total['Time'].str[14:16]
    CI_total['second']=CI_total['Time'].str[17:19]
    CI_total['year']=pd.to_numeric(CI_total['year'])
    CI_total['month']=pd.to_numeric(CI_total['month'])
    CI_total['day']=pd.to_numeric(CI_total['day'])
    CI_total['hour']=pd.to_numeric(CI_total['hour'])
    CI_total['minute']=pd.to_numeric(CI_total['minute'])
    CI_total['second']=pd.to_numeric(CI_total['second'])
    CI_total['second2']=(CI_total['second']//5)*5


    CI_total['timetime']=CI_total['Time'].str[:17]+('0'+CI_total['second2'].astype(str)).str[-2:]
    CI_total['datetime']=pd.to_datetime(CI_total['timetime'],format="%Y-%m-%d %H:%M:%S")


    CI_total2=CI_total[['datetime','CI']]

    CI_total3=CI_total2[CI_total2['CI']!=0]


    CI_total3.drop_duplicates(inplace=True)
    CI_total3.reset_index(inplace=True,drop=True)


    CI_total3.to_csv("D:/postopdelirium_parameters/CI/"+str(i)+'.csv')

# %%
for i in range(len(df)):
    if i<1915:
        a=df['no'][i]-1
        if a>=0 and a<=199:
            folder="D:/postopdelirium_csv/0001_0200/0001_0200/"
        elif a>=200 and a<=399:
            folder="D:/postopdelirium_csv/0201_0400/0201_0400/"
        elif a>=400 and a<=599:
            folder="D:/postopdelirium_csv/0401_0600/0401_0600/"
        elif a>=600 and a<=799:
            folder="D:/postopdelirium_csv/0601_0800/0601_0800/"
        elif a>=800 and a<=825:
            folder="D:/postopdelirium_csv/0801_/0801_/"    
        elif a>=826 and a<=999:
            folder="D:/postopdelirium_csv/0827_1000/0827_1000/"
        elif a>=1000 and a<=1199:
            folder="D:/postopdelirium_csv/1001_1200/1001_1200/"
        elif a>=1200 and a<=1399:
            folder="D:/postopdelirium_csv/1201_1400/1201_1400/"
        elif a>=1400 and a<=1649:
            folder="D:/postopdelirium_csv/1401_1650/1401_1650/"
        elif a>=1650 and a<=1799:
            folder="D:/postopdelirium_csv/1651_1800/1651_1800/"
        else:
            folder="D:/postopdelirium_csv/1801_1968/1801_1968/"
    else:
        folder="E:/Workspace/Data/Postopdelirium/postopdelirium_validation_csv/delirium_validation_vitaldb_1_210/"

    
    CI_total=pd.DataFrame(columns=['Time','CI'])
    dftemp_final1=pd.DataFrame(columns=['Time','CI'])

    for filefile in ['파일이름_01','파일이름_02','파일이름_03','파일이름_04','파일이름_05','파일이름_06','파일이름_07','파일이름_08']:      
        try:
            dat=pd.read_csv(findfile(df[filefile][i],folder))
            try:
                dat['Vigilance/CI']
             
                datcolumns=list(dat.columns)
                ci_columns=[]
                for c in datcolumns:
                    if c[:12]=='Vigilance/CI' and c[:17]!='Vigilance/CI_STAT':
                        ci_columns.append(c)
                dfcount=0
                for c in ci_columns:
                    globals()['dftemp_{}'.format(dfcount)]=dat[['Time',c]]
                    globals()['dftemp_{}'.format(dfcount)].columns=['Time','CI']
                    globals()['dftemp_{}'.format(dfcount)]=globals()['dftemp_{}'.format(dfcount)].dropna(axis=0)

                    dfcount+=1
                
                for c in range(dfcount):
                    dftemp_final1=pd.concat([dftemp_final1,globals()['dftemp_{}'.format(c)]])
                
            except:
                pass   
        except:
            pass

    CI_total=dftemp_final1
    CI_total=CI_total.dropna(axis=0)

    CI_total.drop_duplicates(inplace=True)
    CI_total.sort_values(by=['Time'],axis=0,inplace=True)

    CI_total.reset_index(inplace=True,drop=True)



    CI_total['year']=CI_total['Time'].str[:4]
    CI_total['month']=CI_total['Time'].str[5:7]
    CI_total['day']=CI_total['Time'].str[8:10]
    CI_total['hour']=CI_total['Time'].str[11:13]
    CI_total['minute']=CI_total['Time'].str[14:16]
    CI_total['second']=CI_total['Time'].str[17:19]
    CI_total['year']=pd.to_numeric(CI_total['year'])
    CI_total['month']=pd.to_numeric(CI_total['month'])
    CI_total['day']=pd.to_numeric(CI_total['day'])
    CI_total['hour']=pd.to_numeric(CI_total['hour'])
    CI_total['minute']=pd.to_numeric(CI_total['minute'])
    CI_total['second']=pd.to_numeric(CI_total['second'])
    CI_total['second2']=(CI_total['second']//5)*5


    CI_total['timetime']=CI_total['Time'].str[:17]+('0'+CI_total['second2'].astype(str)).str[-2:]
    CI_total['datetime']=pd.to_datetime(CI_total['timetime'],format="%Y-%m-%d %H:%M:%S")


    CI_total2=CI_total[['datetime','CI']]

    CI_total3=CI_total2[CI_total2['CI']!=0]


    CI_total3.drop_duplicates(inplace=True)
    CI_total3.reset_index(inplace=True,drop=True)


    CI_total3.to_csv("D:/postopdelirium_parameters/CI2/"+str(i)+'.csv')

# %%
CI_avail_hemosphere=[]

    
for i in range(len(df)):
    if True: 
        if df['op_type'][i]!=0:
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)
                CPB_on_time=get_CPB_on_time(i)
                CPB_off_time=get_CPB_off_time(i)

                total_anes_minus_CPB_time=(anes_end_time-anes_start_time).seconds-(CPB_off_time-CPB_on_time).seconds

                CI_df=pd.read_csv("D:/postopdelirium_parameters/CI/"+str(i)+'.csv')
                CI_df['datetime']=pd.to_datetime(CI_df['datetime'],format="%Y-%m-%d %H:%M:%S")
                count=0

                for j in range(len(CI_df)):

                    timestamp=CI_df['datetime'][j]
                    if (timestamp>=anes_start_time and timestamp<=CPB_on_time) or (timestamp>=CPB_off_time and timestamp<=anes_end_time):
                        count+=1

                CI_avail_hemosphere.append(count/(total_anes_minus_CPB_time//5))          

            except:
                print(i,'error')  
                CI_avail_hemosphere.append(0)
        else:
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)


                total_anes_time=(anes_end_time-anes_start_time).seconds

                CI_df=pd.read_csv("D:/postopdelirium_parameters/CI/"+str(i)+'.csv')
                CI_df['datetime']=pd.to_datetime(CI_df['datetime'],format="%Y-%m-%d %H:%M:%S")
                count=0

                for j in range(len(CI_df)):

                    timestamp=CI_df['datetime'][j]
                    if timestamp>=anes_start_time and timestamp<=anes_end_time:
                        count+=1

                CI_avail_hemosphere.append(count/(total_anes_time//5))          

            except:
                print(i,'error')  ##anes end time이 애초에 없어서 에러뜸 797 737
                CI_avail_hemosphere.append(0)
    else:
        print(i,'===excluded===')
        CI_avail_hemosphere.append(0)

df['CI_avail_hemosphere']=CI_avail_hemosphere

# %%
CI_avail_vigilance=[]

    
for i in range(len(df)):
    if True: 
        if df['op_type'][i]!=0:
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)
                CPB_on_time=get_CPB_on_time(i)
                CPB_off_time=get_CPB_off_time(i)

                total_anes_minus_CPB_time=(anes_end_time-anes_start_time).seconds-(CPB_off_time-CPB_on_time).seconds

                CI_df=pd.read_csv("D:/postopdelirium_parameters/CI2/"+str(i)+'.csv')
                CI_df['datetime']=pd.to_datetime(CI_df['datetime'],format="%Y-%m-%d %H:%M:%S")
                count=0

                for j in range(len(CI_df)):

                    timestamp=CI_df['datetime'][j]
                    if (timestamp>=anes_start_time and timestamp<=CPB_on_time) or (timestamp>=CPB_off_time and timestamp<=anes_end_time):
                        count+=1

                CI_avail_vigilance.append(count/(total_anes_minus_CPB_time//5))          

            except:
                print(i,'error') 
                CI_avail_vigilance.append(0)
        else:
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)


                total_anes_time=(anes_end_time-anes_start_time).seconds

                CI_df=pd.read_csv("D:/postopdelirium_parameters/CI2/"+str(i)+'.csv')
                CI_df['datetime']=pd.to_datetime(CI_df['datetime'],format="%Y-%m-%d %H:%M:%S")
                count=0

                for j in range(len(CI_df)):

                    timestamp=CI_df['datetime'][j]
                    if timestamp>=anes_start_time and timestamp<=anes_end_time:
                        count+=1

                CI_avail_vigilance.append(count/(total_anes_time//5))          

            except:
                print(i,'error')  
                CI_avail_vigilance.append(0)
    else:
        print(i,'===excluded===')
        CI_avail_vigilance.append(0)

df['CI_avail_vigilance']=CI_avail_vigilance

# %%
CI_type_list=[]
CI_avail=[]
hemocount=0
for i in range(len(df)):
    h=df['CI_avail_hemosphere'][i]
    v=df['CI_avail_vigilance'][i]
    if h>=v:
        CI_type_list.append('hemosphere')
        CI_avail.append(h)
        hemocount+=1
    else:
        CI_type_list.append('vigilance')
        CI_avail.append(v)
df['CI_type']=CI_type_list
df['CI_avail']=CI_avail
print(hemocount)

# %%
plt.hist(CI_avail)

# %%
##CI_mean, CI_duration_2,CI_auc_2


CI_mean_list=[]
CI_duration_2_list=[]
CI_auc_2_list=[]



for i in range(len(df)):
    if df['CI_type'][i]=='hemosphere': 
        CI_df=pd.read_csv("D:/postopdelirium_parameters/CI/"+str(i)+'.csv')
        CI_df['datetime']=pd.to_datetime(CI_df['datetime'],format="%Y-%m-%d %H:%M:%S")

        CI_mean=np.nan
        CI_duration_2=np.nan
        CI_auc_2=np.nan


        CI_values=[]

        if df['op_type'][i]!=0:

            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)
                CPB_on_time=get_CPB_on_time(i)
                CPB_off_time=get_CPB_off_time(i)


                for j in range(len(CI_df)):          
                    timestamp=CI_df['datetime'][j]
                    if (timestamp>=anes_start_time and timestamp<=CPB_on_time) or (timestamp>=CPB_off_time and timestamp<=anes_end_time):
                        CI_values.append(CI_df['CI'][j].item())

                if len(CI_values)>0:
                    CI_mean=np.mean(CI_values)
                    count_2=0
                    area_2=0

                    for j in range(len(CI_values)):
                        if CI_values[j]<2:
                            count_2+=1
                            area_2+=(2-CI_values[j])


                    CI_duration_2=count_2
                    CI_auc_2=area_2


                CI_mean_list.append(CI_mean)
                CI_duration_2_list.append(CI_duration_2)
                CI_auc_2_list.append(CI_auc_2)

                #print(i)


            except:
                print(i,'error')
                CI_mean_list.append(CI_mean)
                CI_duration_2_list.append(CI_duration_2)
                CI_auc_2_list.append(CI_auc_2)
        else:
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)


                for j in range(len(CI_df)):          
                    timestamp=CI_df['datetime'][j]
                    if timestamp>=anes_start_time and timestamp<=anes_end_time:
                        CI_values.append(CI_df['CI'][j].item())

                if len(CI_values)>0:
                    CI_mean=np.mean(CI_values)
                    count_2=0
                    area_2=0

                    for j in range(len(CI_values)):
                        if CI_values[j]<2:
                            count_2+=1
                            area_2+=(2-CI_values[j])


                    CI_duration_2=count_2
                    CI_auc_2=area_2


                CI_mean_list.append(CI_mean)
                CI_duration_2_list.append(CI_duration_2)
                CI_auc_2_list.append(CI_auc_2)


            except:
                print(i,'error')
                CI_mean_list.append(CI_mean)
                CI_duration_2_list.append(CI_duration_2)
                CI_auc_2_list.append(CI_auc_2)
    else:
        CI_df=pd.read_csv("D:/postopdelirium_parameters/CI2/"+str(i)+'.csv')
        CI_df['datetime']=pd.to_datetime(CI_df['datetime'],format="%Y-%m-%d %H:%M:%S")

        CI_mean=np.nan
        CI_duration_2=np.nan
        CI_auc_2=np.nan


        CI_values=[]

        if df['op_type'][i]!=0:

            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)
                CPB_on_time=get_CPB_on_time(i)
                CPB_off_time=get_CPB_off_time(i)
                #op_end_time=get_op_end_time(i)
                #op_start_time=get_op_start_time(i)

                for j in range(len(CI_df)):          
                    timestamp=CI_df['datetime'][j]
                    if (timestamp>=anes_start_time and timestamp<=CPB_on_time) or (timestamp>=CPB_off_time and timestamp<=anes_end_time):
                        CI_values.append(CI_df['CI'][j].item())

                if len(CI_values)>0:
                    CI_mean=np.mean(CI_values)
                    count_2=0
                    area_2=0

                    for j in range(len(CI_values)):
                        if CI_values[j]<2:
                            count_2+=1
                            area_2+=(2-CI_values[j])


                    CI_duration_2=count_2
                    CI_auc_2=area_2


                CI_mean_list.append(CI_mean)
                CI_duration_2_list.append(CI_duration_2)
                CI_auc_2_list.append(CI_auc_2)


            except:
                print(i,'error')
                CI_mean_list.append(CI_mean)
                CI_duration_2_list.append(CI_duration_2)
                CI_auc_2_list.append(CI_auc_2)
        else:
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)


                for j in range(len(CI_df)):          
                    timestamp=CI_df['datetime'][j]
                    if timestamp>=anes_start_time and timestamp<=anes_end_time:
                        CI_values.append(CI_df['CI'][j].item())

                if len(CI_values)>0:
                    CI_mean=np.mean(CI_values)
                    count_2=0
                    area_2=0

                    for j in range(len(CI_values)):
                        if CI_values[j]<2:
                            count_2+=1
                            area_2+=(2-CI_values[j])


                    CI_duration_2=count_2
                    CI_auc_2=area_2


                CI_mean_list.append(CI_mean)
                CI_duration_2_list.append(CI_duration_2)
                CI_auc_2_list.append(CI_auc_2)

            except:
                print(i,'error')
                CI_mean_list.append(CI_mean)
                CI_duration_2_list.append(CI_duration_2)
                CI_auc_2_list.append(CI_auc_2)
        
        
df['CI_mean_list']=CI_mean_list
df['CI_duration_2_list']=CI_duration_2_list
df['CI_auc_2_list']=CI_auc_2_list

# %%
##GAS_auc


for i in range(len(df)):
    if i<1915:
        a=df['no'][i]-1
        if a>=0 and a<=199:
            folder="D:/postopdelirium_csv/0001_0200/0001_0200/"
        elif a>=200 and a<=399:
            folder="D:/postopdelirium_csv/0201_0400/0201_0400/"
        elif a>=400 and a<=599:
            folder="D:/postopdelirium_csv/0401_0600/0401_0600/"
        elif a>=600 and a<=799:
            folder="D:/postopdelirium_csv/0601_0800/0601_0800/"
        elif a>=800 and a<=825:
            folder="D:/postopdelirium_csv/0801_/0801_/"    
        elif a>=826 and a<=999:
            folder="D:/postopdelirium_csv/0827_1000/0827_1000/"
        elif a>=1000 and a<=1199:
            folder="D:/postopdelirium_csv/1001_1200/1001_1200/"
        elif a>=1200 and a<=1399:
            folder="D:/postopdelirium_csv/1201_1400/1201_1400/"
        elif a>=1400 and a<=1649:
            folder="D:/postopdelirium_csv/1401_1650/1401_1650/"
        elif a>=1650 and a<=1799:
            folder="D:/postopdelirium_csv/1651_1800/1651_1800/"
        else:
            folder="D:/postopdelirium_csv/1801_1968/1801_1968/"
    else:
        folder="E:/Workspace/Data/Postopdelirium/postopdelirium_validation_csv/delirium_validation_vitaldb_1_210/"

    
    GAS_total=pd.DataFrame(columns=['Time','GAS'])
    dftemp_final1=pd.DataFrame(columns=['Time','GAS'])
    if i!=180:
        for filefile in ['파일이름_01','파일이름_02','파일이름_03','파일이름_04','파일이름_05','파일이름_06','파일이름_07','파일이름_08']:      
            try:
                dat=pd.read_csv(findfile(df[filefile][i],folder))
                try:
                    dat['Primus/GAS2_EXPIRED']
                    datcolumns=list(dat.columns)
                    gas_columns=[]
                    for c in datcolumns:
                        if c[:19]=='Primus/GAS2_EXPIRED':
                            gas_columns.append(c)
                    dfcount=0
                    for c in gas_columns:
                        globals()['dftemp_{}'.format(dfcount)]=dat[['Time',c]]
                        globals()['dftemp_{}'.format(dfcount)].columns=['Time','GAS']
                        globals()['dftemp_{}'.format(dfcount)]=globals()['dftemp_{}'.format(dfcount)].dropna(axis=0)

                        dfcount+=1
                    for c in range(dfcount):
                        dftemp_final1=pd.concat([dftemp_final1,globals()['dftemp_{}'.format(c)]])
                    
                except:
                    pass   
            except:
                pass
    else:
        for filefile in ['파일이름_01','파일이름_02','파일이름_03','파일이름_04']:      
            try:
                dat=pd.read_csv(findfile(df[filefile][i],folder))
                try:
                    dat['Primus/GAS2_EXPIRED']
                    datcolumns=list(dat.columns)
                    gas_columns=[]
                    for c in datcolumns:
                        if c[:19]=='Primus/GAS2_EXPIRED':
                            gas_columns.append(c)
                    dfcount=0
                    for c in gas_columns:
                        globals()['dftemp_{}'.format(dfcount)]=dat[['Time',c]]
                        globals()['dftemp_{}'.format(dfcount)].columns=['Time','GAS']
                        globals()['dftemp_{}'.format(dfcount)]=globals()['dftemp_{}'.format(dfcount)].dropna(axis=0)
                        #print(dftemp_0)
                        dfcount+=1
                    for c in range(dfcount):
                        dftemp_final1=pd.concat([dftemp_final1,globals()['dftemp_{}'.format(c)]])
                    
                except:
                    pass   
            except:
                pass

    GAS_total=dftemp_final1
    GAS_total=GAS_total.dropna(axis=0)

    GAS_total.drop_duplicates(inplace=True)
    GAS_total.sort_values(by=['Time'],axis=0,inplace=True)

    GAS_total.reset_index(inplace=True,drop=True)


    GAS_total['year']=GAS_total['Time'].str[:4]
    GAS_total['month']=GAS_total['Time'].str[5:7]
    GAS_total['day']=GAS_total['Time'].str[8:10]
    GAS_total['hour']=GAS_total['Time'].str[11:13]
    GAS_total['minute']=GAS_total['Time'].str[14:16]
    GAS_total['second']=GAS_total['Time'].str[17:19]
    GAS_total['year']=pd.to_numeric(GAS_total['year'])
    GAS_total['month']=pd.to_numeric(GAS_total['month'])
    GAS_total['day']=pd.to_numeric(GAS_total['day'])
    GAS_total['hour']=pd.to_numeric(GAS_total['hour'])
    GAS_total['minute']=pd.to_numeric(GAS_total['minute'])
    GAS_total['second']=pd.to_numeric(GAS_total['second'])
    GAS_total['second2']=(GAS_total['second']//5)*5

    GAS_total['timetime']=GAS_total['Time'].str[:17]+('0'+GAS_total['second2'].astype(str)).str[-2:]
    GAS_total['datetime']=pd.to_datetime(GAS_total['timetime'],format="%Y-%m-%d %H:%M:%S")

    GAS_total2=GAS_total[['datetime','GAS']]



    GAS_total2.drop_duplicates(inplace=True)
    GAS_total2.reset_index(inplace=True,drop=True)



    GAS_total2.to_csv("D:/postopdelirium_parameters/GAS/"+str(i)+'.csv')
    #print(i)

# %%
GAS_avail=[]

for i in range(len(df)):
    if True: 
        if df['op_type'][i]!=0:
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)
                CPB_on_time=get_CPB_on_time(i)
                CPB_off_time=get_CPB_off_time(i)

                total_anes_minus_CPB_time=(anes_end_time-anes_start_time).seconds-(CPB_off_time-CPB_on_time).seconds

                GAS_df=pd.read_csv("D:/postopdelirium_parameters/GAS/"+str(i)+'.csv')
                GAS_df['datetime']=pd.to_datetime(GAS_df['datetime'],format="%Y-%m-%d %H:%M:%S")
                count=0

                for j in range(len(GAS_df)):

                    timestamp=GAS_df['datetime'][j]
                    if (timestamp>=anes_start_time and timestamp<=CPB_on_time) or (timestamp>=CPB_off_time and timestamp<=anes_end_time):
                        count+=1

                GAS_avail.append(count/(total_anes_minus_CPB_time//5))          

            except:
                print(i,'error')  
                GAS_avail.append(0)
        else:
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)


                total_anes_time=(anes_end_time-anes_start_time).seconds

                GAS_df=pd.read_csv("D:/postopdelirium_parameters/GAS/"+str(i)+'.csv')
                GAS_df['datetime']=pd.to_datetime(GAS_df['datetime'],format="%Y-%m-%d %H:%M:%S")
                count=0

                for j in range(len(GAS_df)):

                    timestamp=GAS_df['datetime'][j]
                    if timestamp>=anes_start_time and timestamp<=anes_end_time:
                        count+=1

                GAS_avail.append(count/(total_anes_time//5))          

            except:
                print(i,'error')  
                GAS_avail.append(0)
    else:
        print(i,'===excluded===')
        GAS_avail.append(0)

df['GAS_avail']=GAS_avail

# %%
plt.hist(GAS_avail)

# %%
##GAS_auc


GAS_auc_list=[]


for i in range(len(df)):
    if True: 
        GAS_df=pd.read_csv("D:/postopdelirium_parameters/GAS/"+str(i)+'.csv')
        GAS_df['datetime']=pd.to_datetime(GAS_df['datetime'],format="%Y-%m-%d %H:%M:%S")

        GAS_auc=np.nan


        GAS_values=[]
        if df['op_type'][i]!=0:

            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)
                CPB_on_time=get_CPB_on_time(i)
                CPB_off_time=get_CPB_off_time(i)


                for j in range(len(GAS_df)):          
                    timestamp=GAS_df['datetime'][j]
                    if (timestamp>=anes_start_time and timestamp<=CPB_on_time) or (timestamp>=CPB_off_time and timestamp<=anes_end_time):
                        GAS_values.append(GAS_df['GAS'][j].item())

                if len(GAS_values)>0:

                    area=0

                    for j in range(len(GAS_values)):
                        area+=GAS_values[j]


                    GAS_auc=area


                GAS_auc_list.append(GAS_auc)



            except:
                print(i,'error')
                GAS_auc_list.append(GAS_auc)
        else:
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)

                for j in range(len(GAS_df)):          
                    timestamp=GAS_df['datetime'][j]
                    if timestamp>=anes_start_time and timestamp<=anes_end_time:
                        GAS_values.append(GAS_df['GAS'][j].item())

                if len(GAS_values)>0:

                    area=0

                    for j in range(len(GAS_values)):
                        area+=GAS_values[j]


                    GAS_auc=area


                GAS_auc_list.append(GAS_auc)


            except:
                print(i,'error')
                GAS_auc_list.append(GAS_auc)
    else:
        print(i,'===excluded===')
        GAS_auc=np.nan
        GAS_auc_list.append(GAS_auc)


        
df['GAS_auc_list']=GAS_auc_list

# %%
##SpO2_duration_93

for i in range(len(df)):
    if i<1915:
        a=df['no'][i]-1
        if a>=0 and a<=199:
            folder="D:/postopdelirium_csv/0001_0200/0001_0200/"
        elif a>=200 and a<=399:
            folder="D:/postopdelirium_csv/0201_0400/0201_0400/"
        elif a>=400 and a<=599:
            folder="D:/postopdelirium_csv/0401_0600/0401_0600/"
        elif a>=600 and a<=799:
            folder="D:/postopdelirium_csv/0601_0800/0601_0800/"
        elif a>=800 and a<=825:
            folder="D:/postopdelirium_csv/0801_/0801_/"    
        elif a>=826 and a<=999:
            folder="D:/postopdelirium_csv/0827_1000/0827_1000/"
        elif a>=1000 and a<=1199:
            folder="D:/postopdelirium_csv/1001_1200/1001_1200/"
        elif a>=1200 and a<=1399:
            folder="D:/postopdelirium_csv/1201_1400/1201_1400/"
        elif a>=1400 and a<=1649:
            folder="D:/postopdelirium_csv/1401_1650/1401_1650/"
        elif a>=1650 and a<=1799:
            folder="D:/postopdelirium_csv/1651_1800/1651_1800/"
        else:
            folder="D:/postopdelirium_csv/1801_1968/1801_1968/"
    else:
        folder="E:/Workspace/Data/Postopdelirium/postopdelirium_validation_csv/delirium_validation_vitaldb_1_210/"
    
    
    
    SpO2_total=pd.DataFrame(columns=['Time','SpO2'])
    dftemp_final1=pd.DataFrame(columns=['Time','SpO2'])
    for filefile in ['파일이름_01','파일이름_02','파일이름_03','파일이름_04','파일이름_05','파일이름_06','파일이름_07','파일이름_08']:      
        try:
            dat=pd.read_csv(findfile(df[filefile][i],folder))
            try:
                dat['Intellivue/PLETH_SAT_O2']
                datcolumns=list(dat.columns)
                spo2_columns=[]
                for c in datcolumns:
                    if c[:23]=='Intellivue/PLETH_SAT_O2':
                        spo2_columns.append(c)
                dfcount=0
                for c in spo2_columns:
                    globals()['dftemp_{}'.format(dfcount)]=dat[['Time',c]]
                    globals()['dftemp_{}'.format(dfcount)].columns=['Time','SpO2']
                    globals()['dftemp_{}'.format(dfcount)]=globals()['dftemp_{}'.format(dfcount)].dropna(axis=0)

                    dfcount+=1
                for c in range(dfcount):
                    dftemp_final1=pd.concat([dftemp_final1,globals()['dftemp_{}'.format(c)]])

            except:
                pass  

        except:
            pass

    SpO2_total=dftemp_final1
    SpO2_total=SpO2_total.dropna(axis=0)

    SpO2_total.drop_duplicates(inplace=True)
    SpO2_total.sort_values(by=['Time'],axis=0,inplace=True)

    SpO2_total.reset_index(inplace=True,drop=True)



    SpO2_total['year']=SpO2_total['Time'].str[:4]
    SpO2_total['month']=SpO2_total['Time'].str[5:7]
    SpO2_total['day']=SpO2_total['Time'].str[8:10]
    SpO2_total['hour']=SpO2_total['Time'].str[11:13]
    SpO2_total['minute']=SpO2_total['Time'].str[14:16]
    SpO2_total['second']=SpO2_total['Time'].str[17:19]
    SpO2_total['year']=pd.to_numeric(SpO2_total['year'])
    SpO2_total['month']=pd.to_numeric(SpO2_total['month'])
    SpO2_total['day']=pd.to_numeric(SpO2_total['day'])
    SpO2_total['hour']=pd.to_numeric(SpO2_total['hour'])
    SpO2_total['minute']=pd.to_numeric(SpO2_total['minute'])
    SpO2_total['second']=pd.to_numeric(SpO2_total['second'])
    SpO2_total['second2']=(SpO2_total['second']//5)*5

    SpO2_total['timetime']=SpO2_total['Time'].str[:17]+('0'+SpO2_total['second2'].astype(str)).str[-2:]
    SpO2_total['datetime']=pd.to_datetime(SpO2_total['timetime'],format="%Y-%m-%d %H:%M:%S")

    SpO2_total2=SpO2_total[['datetime','SpO2']]



    SpO2_total2.drop_duplicates(inplace=True)
    SpO2_total2.reset_index(inplace=True,drop=True)

    SpO2_total2.to_csv("D:/postopdelirium_parameters/SpO2/"+str(i)+'.csv')

# %%
SpO2_avail=[]

for i in range(len(df)):
    if True: 
        if df['op_type'][i]!=0:
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)
                CPB_on_time=get_CPB_on_time(i)
                CPB_off_time=get_CPB_off_time(i)

                total_anes_minus_CPB_time=(anes_end_time-anes_start_time).seconds-(CPB_off_time-CPB_on_time).seconds

                SpO2_df=pd.read_csv("D:/postopdelirium_parameters/SpO2/"+str(i)+'.csv')
                SpO2_df['datetime']=pd.to_datetime(SpO2_df['datetime'],format="%Y-%m-%d %H:%M:%S")
                count=0

                for j in range(len(SpO2_df)):

                    timestamp=SpO2_df['datetime'][j]
                    if (timestamp>=anes_start_time and timestamp<=CPB_on_time) or (timestamp>=CPB_off_time and timestamp<=anes_end_time):
                        count+=1

                SpO2_avail.append(count/(total_anes_minus_CPB_time//5))          

            except:
                print(i,'error')  
                SpO2_avail.append(0)
        else:
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)

                total_anes_time=(anes_end_time-anes_start_time).seconds

                SpO2_df=pd.read_csv("D:/postopdelirium_parameters/SpO2/"+str(i)+'.csv')
                SpO2_df['datetime']=pd.to_datetime(SpO2_df['datetime'],format="%Y-%m-%d %H:%M:%S")
                count=0

                for j in range(len(SpO2_df)):

                    timestamp=SpO2_df['datetime'][j]
                    if timestamp>=anes_start_time and timestamp<=anes_end_time:
                        count+=1

                SpO2_avail.append(count/(total_anes_time//5))          

            except:
                print(i,'error')  
                SpO2_avail.append(0)
    else:
        print(i,'===excluded===')
        SpO2_avail.append(0)

df['SpO2_avail']=SpO2_avail

# %%
plt.hist(SpO2_avail)

# %%
##SpO2_duration_93


SpO2_duration_93_list=[]



for i in range(len(df)):
    if True: 
        SpO2_df=pd.read_csv("D:/postopdelirium_parameters/SpO2/"+str(i)+'.csv')
        SpO2_df['datetime']=pd.to_datetime(SpO2_df['datetime'],format="%Y-%m-%d %H:%M:%S")

        SpO2_duration_93=np.nan


        SpO2_values=[]
        if df['op_type'][i]!=0:
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)
                CPB_on_time=get_CPB_on_time(i)
                CPB_off_time=get_CPB_off_time(i)


                for j in range(len(SpO2_df)):          
                    timestamp=SpO2_df['datetime'][j]
                    if (timestamp>=anes_start_time and timestamp<=CPB_on_time) or (timestamp>=CPB_off_time and timestamp<=anes_end_time):
                        SpO2_values.append(SpO2_df['SpO2'][j].item())

                if len(SpO2_values)>0:

                    count=0

                    for j in range(len(SpO2_values)):
                        if SpO2_values[j]<93:
                            count+=1


                    SpO2_duration_93=count


                SpO2_duration_93_list.append(SpO2_duration_93)


            except:
                print(i,'error')
                SpO2_duration_93_list.append(SpO2_duration_93)
        else:
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)

                for j in range(len(SpO2_df)):          
                    timestamp=SpO2_df['datetime'][j]
                    if timestamp>=anes_start_time and timestamp<=anes_end_time:
                        SpO2_values.append(SpO2_df['SpO2'][j].item())

                if len(SpO2_values)>0:

                    count=0

                    for j in range(len(SpO2_values)):
                        if SpO2_values[j]<93:
                            count+=1


                    SpO2_duration_93=count


                SpO2_duration_93_list.append(SpO2_duration_93)



            except:
                print(i,'error')
                SpO2_duration_93_list.append(SpO2_duration_93)
    else:
        print(i,'===excluded===')
        SpO2_duration_93=np.nan
        SpO2_duration_93_list.append(SpO2_duration_93)
    
        
        
df['SpO2_duration_93_list']=SpO2_duration_93_list

# %%
##SvO2_mean
##SvO2_duration_60
##SvO2_auc_60


for i in range(len(df)):
    if i<1915:
        a=df['no'][i]-1
        if a>=0 and a<=199:
            folder="D:/postopdelirium_csv/0001_0200/0001_0200/"
        elif a>=200 and a<=399:
            folder="D:/postopdelirium_csv/0201_0400/0201_0400/"
        elif a>=400 and a<=599:
            folder="D:/postopdelirium_csv/0401_0600/0401_0600/"
        elif a>=600 and a<=799:
            folder="D:/postopdelirium_csv/0601_0800/0601_0800/"
        elif a>=800 and a<=825:
            folder="D:/postopdelirium_csv/0801_/0801_/"    
        elif a>=826 and a<=999:
            folder="D:/postopdelirium_csv/0827_1000/0827_1000/"
        elif a>=1000 and a<=1199:
            folder="D:/postopdelirium_csv/1001_1200/1001_1200/"
        elif a>=1200 and a<=1399:
            folder="D:/postopdelirium_csv/1201_1400/1201_1400/"
        elif a>=1400 and a<=1649:
            folder="D:/postopdelirium_csv/1401_1650/1401_1650/"
        elif a>=1650 and a<=1799:
            folder="D:/postopdelirium_csv/1651_1800/1651_1800/"
        else:
            folder="D:/postopdelirium_csv/1801_1968/1801_1968/"
    else:
        folder="E:/Workspace/Data/Postopdelirium/postopdelirium_validation_csv/delirium_validation_vitaldb_1_210/"

    dftemp_final1=pd.DataFrame(columns=['Time','SvO2'])
    SvO2_total=pd.DataFrame(columns=['Time','SvO2'])
    for filefile in ['파일이름_01','파일이름_02','파일이름_03','파일이름_04','파일이름_05','파일이름_06','파일이름_07','파일이름_08']:      
        try:
            dat=pd.read_csv(findfile(df[filefile][i],folder))
            try:
                dat['Hemosphere/SVO2']
                datcolumns=list(dat.columns)
                svo2_columns=[]
                for c in datcolumns:
                    if c[:15]=='Hemosphere/SVO2':
                        svo2_columns.append(c)
                dfcount=0
                for c in svo2_columns:
                    globals()['dftemp_{}'.format(dfcount)]=dat[['Time',c]]
                    globals()['dftemp_{}'.format(dfcount)].columns=['Time','SvO2']
                    globals()['dftemp_{}'.format(dfcount)]=globals()['dftemp_{}'.format(dfcount)].dropna(axis=0)

                    dfcount+=1
                for c in range(dfcount):
                    dftemp_final1=pd.concat([dftemp_final1,globals()['dftemp_{}'.format(c)]])

            except:
                pass 
  
        except:
            pass

    SvO2_total=dftemp_final1
    SvO2_total=SvO2_total.dropna(axis=0)

    SvO2_total.drop_duplicates(inplace=True)
    SvO2_total.sort_values(by=['Time'],axis=0,inplace=True)

    SvO2_total.reset_index(inplace=True,drop=True)


    SvO2_total['year']=SvO2_total['Time'].str[:4]
    SvO2_total['month']=SvO2_total['Time'].str[5:7]
    SvO2_total['day']=SvO2_total['Time'].str[8:10]
    SvO2_total['hour']=SvO2_total['Time'].str[11:13]
    SvO2_total['minute']=SvO2_total['Time'].str[14:16]
    SvO2_total['second']=SvO2_total['Time'].str[17:19]
    SvO2_total['year']=pd.to_numeric(SvO2_total['year'])
    SvO2_total['month']=pd.to_numeric(SvO2_total['month'])
    SvO2_total['day']=pd.to_numeric(SvO2_total['day'])
    SvO2_total['hour']=pd.to_numeric(SvO2_total['hour'])
    SvO2_total['minute']=pd.to_numeric(SvO2_total['minute'])
    SvO2_total['second']=pd.to_numeric(SvO2_total['second'])
    SvO2_total['second2']=(SvO2_total['second']//5)*5

    SvO2_total['timetime']=SvO2_total['Time'].str[:17]+('0'+SvO2_total['second2'].astype(str)).str[-2:]
    SvO2_total['datetime']=pd.to_datetime(SvO2_total['timetime'],format="%Y-%m-%d %H:%M:%S")

    SvO2_total2=SvO2_total[['datetime','SvO2']]



    SvO2_total2.drop_duplicates(inplace=True)
    SvO2_total2.reset_index(inplace=True,drop=True)

    SvO2_total2.to_csv("D:/postopdelirium_parameters/SvO2/"+str(i)+'.csv')

# %%
##SvO2_mean
##SvO2_duration_60
##SvO2_auc_60


for i in range(len(df)):
    if i<1915:
        a=df['no'][i]-1
        if a>=0 and a<=199:
            folder="D:/postopdelirium_csv/0001_0200/0001_0200/"
        elif a>=200 and a<=399:
            folder="D:/postopdelirium_csv/0201_0400/0201_0400/"
        elif a>=400 and a<=599:
            folder="D:/postopdelirium_csv/0401_0600/0401_0600/"
        elif a>=600 and a<=799:
            folder="D:/postopdelirium_csv/0601_0800/0601_0800/"
        elif a>=800 and a<=825:
            folder="D:/postopdelirium_csv/0801_/0801_/"    
        elif a>=826 and a<=999:
            folder="D:/postopdelirium_csv/0827_1000/0827_1000/"
        elif a>=1000 and a<=1199:
            folder="D:/postopdelirium_csv/1001_1200/1001_1200/"
        elif a>=1200 and a<=1399:
            folder="D:/postopdelirium_csv/1201_1400/1201_1400/"
        elif a>=1400 and a<=1649:
            folder="D:/postopdelirium_csv/1401_1650/1401_1650/"
        elif a>=1650 and a<=1799:
            folder="D:/postopdelirium_csv/1651_1800/1651_1800/"
        else:
            folder="D:/postopdelirium_csv/1801_1968/1801_1968/"
    else:
        folder="E:/Workspace/Data/Postopdelirium/postopdelirium_validation_csv/delirium_validation_vitaldb_1_210/"

    dftemp_final1=pd.DataFrame(columns=['Time','SvO2'])
    SvO2_total=pd.DataFrame(columns=['Time','SvO2'])
    for filefile in ['파일이름_01','파일이름_02','파일이름_03','파일이름_04','파일이름_05','파일이름_06','파일이름_07','파일이름_08']:      
        try:
            dat=pd.read_csv(findfile(df[filefile][i],folder))
            try:
                dat['Vigilance/SVO2']
                datcolumns=list(dat.columns)
                svo2_columns=[]
                for c in datcolumns:
                    if c[:14]=='Vigilance/SVO2':
                        svo2_columns.append(c)
                dfcount=0
                for c in svo2_columns:
                    globals()['dftemp_{}'.format(dfcount)]=dat[['Time',c]]
                    globals()['dftemp_{}'.format(dfcount)].columns=['Time','SvO2']
                    globals()['dftemp_{}'.format(dfcount)]=globals()['dftemp_{}'.format(dfcount)].dropna(axis=0)
                    #print(dftemp_0)
                    dfcount+=1
                for c in range(dfcount):
                    dftemp_final1=pd.concat([dftemp_final1,globals()['dftemp_{}'.format(c)]])

            except:
                pass 
  
        except:
            pass

    SvO2_total=dftemp_final1
    SvO2_total=SvO2_total.dropna(axis=0)

    SvO2_total.drop_duplicates(inplace=True)
    SvO2_total.sort_values(by=['Time'],axis=0,inplace=True)

    SvO2_total.reset_index(inplace=True,drop=True)


    SvO2_total['year']=SvO2_total['Time'].str[:4]
    SvO2_total['month']=SvO2_total['Time'].str[5:7]
    SvO2_total['day']=SvO2_total['Time'].str[8:10]
    SvO2_total['hour']=SvO2_total['Time'].str[11:13]
    SvO2_total['minute']=SvO2_total['Time'].str[14:16]
    SvO2_total['second']=SvO2_total['Time'].str[17:19]
    SvO2_total['year']=pd.to_numeric(SvO2_total['year'])
    SvO2_total['month']=pd.to_numeric(SvO2_total['month'])
    SvO2_total['day']=pd.to_numeric(SvO2_total['day'])
    SvO2_total['hour']=pd.to_numeric(SvO2_total['hour'])
    SvO2_total['minute']=pd.to_numeric(SvO2_total['minute'])
    SvO2_total['second']=pd.to_numeric(SvO2_total['second'])
    SvO2_total['second2']=(SvO2_total['second']//5)*5

    SvO2_total['timetime']=SvO2_total['Time'].str[:17]+('0'+SvO2_total['second2'].astype(str)).str[-2:]
    SvO2_total['datetime']=pd.to_datetime(SvO2_total['timetime'],format="%Y-%m-%d %H:%M:%S")

    SvO2_total2=SvO2_total[['datetime','SvO2']]



    SvO2_total2.drop_duplicates(inplace=True)
    SvO2_total2.reset_index(inplace=True,drop=True)

    SvO2_total2.to_csv("D:/postopdelirium_parameters/SvO2_2/"+str(i)+'.csv')

# %%
SvO2_avail_hemosphere=[]

for i in range(len(df)):
    if True: 
        if df['op_type'][i]!=0:
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)
                CPB_on_time=get_CPB_on_time(i)
                CPB_off_time=get_CPB_off_time(i)

                total_anes_minus_CPB_time=(anes_end_time-anes_start_time).seconds-(CPB_off_time-CPB_on_time).seconds

                SvO2_df=pd.read_csv("D:/postopdelirium_parameters/SvO2/"+str(i)+'.csv')
                SvO2_df['datetime']=pd.to_datetime(SvO2_df['datetime'],format="%Y-%m-%d %H:%M:%S")
                count=0

                for j in range(len(SvO2_df)):

                    timestamp=SvO2_df['datetime'][j]
                    if (timestamp>=anes_start_time and timestamp<=CPB_on_time) or (timestamp>=CPB_off_time and timestamp<=anes_end_time):
                        count+=1

                SvO2_avail_hemosphere.append(count/(total_anes_minus_CPB_time//5))          

            except:
                print(i,'error')  
                SvO2_avail_hemosphere.append(0)
        else:
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)


                total_anes_time=(anes_end_time-anes_start_time).seconds

                SvO2_df=pd.read_csv("D:/postopdelirium_parameters/SvO2/"+str(i)+'.csv')
                SvO2_df['datetime']=pd.to_datetime(SvO2_df['datetime'],format="%Y-%m-%d %H:%M:%S")
                count=0

                for j in range(len(SvO2_df)):

                    timestamp=SvO2_df['datetime'][j]
                    if timestamp>=anes_start_time and timestamp<=anes_end_time:
                        count+=1

                SvO2_avail_hemosphere.append(count/(total_anes_time//5))          

            except:
                print(i,'error')  
                SvO2_avail_hemosphere.append(0)
    else:
        print(i,'===excluded===')
        SvO2_avail_hemosphere.append(0)

df['SvO2_avail_hemosphere']=SvO2_avail_hemosphere

# %%
SvO2_avail_vigilance=[]

for i in range(len(df)):
    if True: 
        if df['op_type'][i]!=0:
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)
                CPB_on_time=get_CPB_on_time(i)
                CPB_off_time=get_CPB_off_time(i)

                total_anes_minus_CPB_time=(anes_end_time-anes_start_time).seconds-(CPB_off_time-CPB_on_time).seconds

                SvO2_df=pd.read_csv("D:/postopdelirium_parameters/SvO2_2/"+str(i)+'.csv')
                SvO2_df['datetime']=pd.to_datetime(SvO2_df['datetime'],format="%Y-%m-%d %H:%M:%S")
                count=0

                for j in range(len(SvO2_df)):

                    timestamp=SvO2_df['datetime'][j]
                    if (timestamp>=anes_start_time and timestamp<=CPB_on_time) or (timestamp>=CPB_off_time and timestamp<=anes_end_time):
                        count+=1

                SvO2_avail_vigilance.append(count/(total_anes_minus_CPB_time//5))          

            except:
                print(i,'error')  
                SvO2_avail_vigilance.append(0)
        else:
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)

                total_anes_time=(anes_end_time-anes_start_time).seconds

                SvO2_df=pd.read_csv("D:/postopdelirium_parameters/SvO2_2/"+str(i)+'.csv')
                SvO2_df['datetime']=pd.to_datetime(SvO2_df['datetime'],format="%Y-%m-%d %H:%M:%S")
                count=0

                for j in range(len(SvO2_df)):

                    timestamp=SvO2_df['datetime'][j]
                    if timestamp>=anes_start_time and timestamp<=anes_end_time:
                        count+=1

                SvO2_avail_vigilance.append(count/(total_anes_time//5))          

            except:
                print(i,'error')  
                SvO2_avail_vigilance.append(0)
    else:
        print(i,'===excluded===')
        SvO2_avail_vigilance.append(0)

df['SvO2_avail_vigilance']=SvO2_avail_vigilance

# %%
SvO2_type=[]
SvO2_avail=[]
hemocount=0
for i in range(len(df)):
    h=df['SvO2_avail_hemosphere'][i]
    v=df['SvO2_avail_vigilance'][i]
    if h>=v:
        SvO2_type.append('hemosphere')
        SvO2_avail.append(h)
        hemocount+=1
    else:
        SvO2_type.append('vigilance')
        SvO2_avail.append(v)
df['SvO2_type']=SvO2_type
df['SvO2_avail']=SvO2_avail
print(hemocount)

# %%
plt.hist(SvO2_avail)

# %%
##SvO2_mean
##SvO2_duration_60
##SvO2_auc_60

SvO2_mean_list=[]
SvO2_duration_60_list=[]
SvO2_auc_60_list=[]



for i in range(len(df)):
    print(i)
    if df['SvO2_type'][i]=='hemosphere': 
        SvO2_df=pd.read_csv("D:/postopdelirium_parameters/SvO2/"+str(i)+'.csv')
        SvO2_df=SvO2_df[SvO2_df['SvO2']>=30]
        SvO2_df.reset_index(inplace=True)
        
        
        SvO2_df['datetime']=pd.to_datetime(SvO2_df['datetime'],format="%Y-%m-%d %H:%M:%S")

        SvO2_mean=np.nan
        SvO2_duration_60=np.nan
        SvO2_auc_60=np.nan


        SvO2_values=[]
        if df['op_type'][i]!=0:

            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)
                CPB_on_time=get_CPB_on_time(i)
                CPB_off_time=get_CPB_off_time(i)
                #op_end_time=get_op_end_time(i)
                #op_start_time=get_op_start_time(i)

                for j in range(len(SvO2_df)):          
                    timestamp=SvO2_df['datetime'][j]
                    if (timestamp>=anes_start_time and timestamp<=CPB_on_time) or (timestamp>=CPB_off_time and timestamp<=anes_end_time):
                        SvO2_values.append(SvO2_df['SvO2'][j].item())

                if len(SvO2_values)>0:
                    SvO2_mean=np.mean(SvO2_values)
                    count=0
                    area=0

                    for j in range(len(SvO2_values)):
                        if SvO2_values[j]<60:
                            count+=1
                            area+=(60-SvO2_values[j])

                    SvO2_duration_60=count
                    SvO2_auc_60=area

                SvO2_mean_list.append(SvO2_mean)
                SvO2_duration_60_list.append(SvO2_duration_60)
                SvO2_auc_60_list.append(SvO2_auc_60)



            except:
                print(i,'error')
                SvO2_mean_list.append(SvO2_mean)
                SvO2_duration_60_list.append(SvO2_duration_60)
                SvO2_auc_60_list.append(SvO2_auc_60)
        else:
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)

                for j in range(len(SvO2_df)):          
                    timestamp=SvO2_df['datetime'][j]
                    if timestamp>=anes_start_time and timestamp<=anes_end_time:
                        SvO2_values.append(SvO2_df['SvO2'][j].item())

                if len(SvO2_values)>0:
                    SvO2_mean=np.mean(SvO2_values)
                    count=0
                    area=0

                    for j in range(len(SvO2_values)):
                        if SvO2_values[j]<60:
                            count+=1
                            area+=(60-SvO2_values[j])

                    SvO2_duration_60=count
                    SvO2_auc_60=area

                SvO2_mean_list.append(SvO2_mean)
                SvO2_duration_60_list.append(SvO2_duration_60)
                SvO2_auc_60_list.append(SvO2_auc_60)


            except:
                print(i,'error')
                SvO2_mean_list.append(SvO2_mean)
                SvO2_duration_60_list.append(SvO2_duration_60)
                SvO2_auc_60_list.append(SvO2_auc_60)
    else:
        SvO2_df=pd.read_csv("D:/postopdelirium_parameters/SvO2_2/"+str(i)+'.csv')
        SvO2_df['datetime']=pd.to_datetime(SvO2_df['datetime'],format="%Y-%m-%d %H:%M:%S")
        SvO2_df=SvO2_df[SvO2_df['SvO2']>=30]
        SvO2_df.reset_index(inplace=True)

        SvO2_mean=np.nan
        SvO2_duration_60=np.nan
        SvO2_auc_60=np.nan


        SvO2_values=[]
        if df['op_type'][i]!=0:

            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)
                CPB_on_time=get_CPB_on_time(i)
                CPB_off_time=get_CPB_off_time(i)


                for j in range(len(SvO2_df)):          
                    timestamp=SvO2_df['datetime'][j]
                    if (timestamp>=anes_start_time and timestamp<=CPB_on_time) or (timestamp>=CPB_off_time and timestamp<=anes_end_time):
                        SvO2_values.append(SvO2_df['SvO2'][j].item())

                if len(SvO2_values)>0:
                    SvO2_mean=np.mean(SvO2_values)
                    count=0
                    area=0

                    for j in range(len(SvO2_values)):
                        if SvO2_values[j]<60:
                            count+=1
                            area+=(60-SvO2_values[j])

                    SvO2_duration_60=count
                    SvO2_auc_60=area

                SvO2_mean_list.append(SvO2_mean)
                SvO2_duration_60_list.append(SvO2_duration_60)
                SvO2_auc_60_list.append(SvO2_auc_60)


            except:
                print(i,'error')
                SvO2_mean_list.append(SvO2_mean)
                SvO2_duration_60_list.append(SvO2_duration_60)
                SvO2_auc_60_list.append(SvO2_auc_60)
        else:
            try:
                anes_end_time=get_anes_end_time(i)
                anes_start_time=get_anes_start_time(i)

                for j in range(len(SvO2_df)):          
                    timestamp=SvO2_df['datetime'][j]
                    if timestamp>=anes_start_time and timestamp<=anes_end_time:
                        SvO2_values.append(SvO2_df['SvO2'][j].item())

                if len(SvO2_values)>0:
                    SvO2_mean=np.mean(SvO2_values)
                    count=0
                    area=0

                    for j in range(len(SvO2_values)):
                        if SvO2_values[j]<60:
                            count+=1
                            area+=(60-SvO2_values[j])

                    SvO2_duration_60=count
                    SvO2_auc_60=area

                SvO2_mean_list.append(SvO2_mean)
                SvO2_duration_60_list.append(SvO2_duration_60)
                SvO2_auc_60_list.append(SvO2_auc_60)


            except:
                print(i,'error')
                SvO2_mean_list.append(SvO2_mean)
                SvO2_duration_60_list.append(SvO2_duration_60)
                SvO2_auc_60_list.append(SvO2_auc_60)

        
        
df['SvO2_mean_list']=SvO2_mean_list
df['SvO2_duration_60_list']=SvO2_duration_60_list
df['SvO2_auc_60_list']=SvO2_auc_60_list

# %%
df.to_csv('20230118_SvO2_re.csv')

# %%
df.to_csv('postop5cha_temp_final_20221031.csv')

# %%
df
